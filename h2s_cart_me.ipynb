# %%
! export JAX_PLATFORMS=cpu
# Out:
# /gpfs/cfel/group/cmi/common/psi4/psi4conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %% [markdown]
# # Rovibrational matrix elements of Cartesian tensor operators
#
# Compute matrix elements of spin-rotation tensors on $\text{H}_1$ and $\text{H}_2$ atoms of $\text{H}_2\text{S}$ as well as electric dipole-moment operator in the basis of rovibrational states.

# %%
from typing import Dict, List

import h5py
import jax
import numpy as np
from jax import config
from jax import numpy as jnp
from rovib.c2v import C2V_IRREPS
from rovib.cartens import CART_IND
from rovib.symtop import threej_wang
from scipy.sparse import csr_matrix

config.update("jax_enable_x64", True)

# %% [markdown]
# The spin-rotation matrix elements are computed using the following formula
#
# $$
# M_{\omega,n}^{(J',l',J,l)}=\sum_{v',k'}\sum_{v,k}c_{v',k'}^{(J',\Gamma',l')*}c_{v,k}^{(J,\Gamma,l)}(-1)^{k'}\sum_{\sigma=-\omega}^{\omega}\sum_{\alpha,\beta=x,y,z}
# \left(\begin{array}{ccc}
# J & \omega & J' \\
# k & \sigma & -k'\\
# \end{array}\right)
# U_{\omega\sigma,\alpha\beta}^{(\Omega)}\langle v'|\bar{M}_{\alpha\beta,n}|v\rangle.
# $$
#
# Here, $\Omega=2$ is the rank of spin-rotation tensor, $\omega=0..\Omega$, $n=1$ and 2 for $\text{H}_1$ and $\text{H}_2$, respectively,
# $\bar{M}_{\alpha\beta,n}$ is the electronic spin-rotation tensor (see `h2s_spinrot.py` for details), $v$ and $k$ denote the vibrational and rotational quanta,
# $J$ and $\Gamma$ denote 'good' quantum numbers of the rotational angular momentum and the state symmetry, and $l$ is the state running index within
# a set of states with the same $J$ and $\Gamma$.
# The rovibrational state expansion coefficients $c_{v,k}^{(J,\Gamma,l)}$
# are computed in `h2s_rovib.ipynb` and stored in seperate files
# for different values of $J$ quanta.
# The matrix $U_{\omega\sigma,\alpha\beta}^{(\Omega)}$ transforms Cartesian tensor of rank $\Omega$ into its spherical-tensor representation
# (see `cartens.UMAT_CART_TO_SPHER`).
#
# The rotational part of the expression
# $$
# R_{\omega,k',k,\alpha\beta}^{(J',J)} = \sum_{\sigma=-\omega}^{\omega}
# \left(\begin{array}{ccc}
# J & \omega & J' \\
# k & \sigma & -k'\\
# \end{array}\right)
# U_{\omega\sigma,\alpha\beta}^{(\Omega)}
# $$
# is computed by the `symtop.threej_wang` function where it is transformed from the symmetric-top basis $|J,k\rangle$ ($k=-J..J$) into the so-called Wang's symmetry-adapted basis $|J,k,\tau\rangle$ ($k=0..J$, $\tau=0,1$ is partity as $(-1)^\tau$).
#
# The vibrational matrix elements
# $$
# V_{n,v',v,\alpha\beta} = \langle v'|\bar{M}_{\alpha\beta,n}|v\rangle
# $$
# are computed in `h2s_rovib.ipynb` and stored in file.

# %% [markdown]
# Define functions to load the energies and quantum numbers for selected rovibrational states (`rovib_states`) and to compute the above matrix elements (`tensor_rovib_me`).

# %%
def rovib_states(j: int, state_ind_list: Dict[str, List[int]] = None, pmax: int = 20):
    """Reads rovibrational energies and quanta stored in files for different values
    of the J quantum number (the files are created in `h2s_rovib.ipynb`).

    Optionally, `state_ind_list[symmetry][<list of state indices>]`
    can be used to select specific states by their indices
    for different symmetries.
    """
    h5 = h5py.File(f"h2s_coefficients_pmax{pmax}_j{j}.h5", "r")
    energies = {}
    quanta = {}
    for sym in h5["energies"].keys():
        enr = h5["energies"][sym][:]
        coefs = h5["coefficients"][sym][:]
        vind = h5["vib-indices"][sym][:]
        rind = h5["rot-indices"][sym][:]
        qua = np.array(
            [elem[0].decode("utf-8").split(",") for elem in h5["quanta"][sym][:]]
        )
        if state_ind_list is not None and sym in state_ind_list:
            energies[sym] = enr[state_ind_list[sym]]
            quanta[sym] = qua[state_ind_list[sym]]
        else:
            energies[sym] = enr
            quanta[sym] = qua
    return energies, quanta

# %%
def tensor_rovib_me(
    rank: int,
    j1: int,
    j2: int,
    vib_me: np.ndarray,
    state_ind_list1: Dict[str, List[int]] = None,
    state_ind_list2: Dict[str, List[int]] = None,
    pmax: int = 20,
    linear: bool = False,
    tol: float = 1e-12,
):
    """Computes rovibrational matrix elements of a Cartesian tensor operator.

    This function calculates the rovibrational matrix elements using wavefunctions stored in
    separate files for different values of the J quantum number (the files are creaed in `h2s_rovib.ipynb`).
    The computation is performed for the specified bra (`j1`) and ket (`j2`) values of the J
    quantum number.

    Optionally, `state_ind_list1[symmetry][<list of state indices>]` and `state_ind_list2[...]`
    can be used to select specific bra and ket states by their indices for different symmetries.
    """

    @jax.jit
    def _matelem(vind1, vind2, rind1, rind2, coefs1, coefs2):
        vib_me_ = vib_me2[jnp.ix_(vind1, vind2)]
        me = []
        for omega in rot_me.keys():
            me_ = jnp.einsum(
                "ijc,ijc->ij", vib_me_, rot_me[omega][jnp.ix_(rind1, rind2)]
            )
            me.append(jnp.einsum("ik,ij,jl->kl", jnp.conj(coefs1), me_, coefs2))
        me = jnp.moveaxis(jnp.array(me), 0, -1)
        me = jnp.where(jnp.abs(me) < tol, 0.0, me)
        return me

    # determine the order of Cartesian indices in the Cartesian-to-spherical tensor
    #   transformation matrix (in cartens.CART_IND and symtop.threej_wang)
    cart_ind = [["xyz".index(x) for x in elem] for elem in CART_IND[rank]]

    # reshape vibrational matrix elements such that the order of Cartesian indices
    #   correspond to the order in symtop.threej_wang output
    if rank == 1:
        vib_me2 = jnp.moveaxis(jnp.array([vib_me[:, :, i] for (i,) in cart_ind]), 0, -1)
    elif rank == 2:
        vib_me2 = jnp.moveaxis(
            jnp.array([vib_me[:, :, i, j] for (i, j) in cart_ind]), 0, -1
        )
    else:
        raise ValueError(
            f"Index mapping for tensor of rank = {rank} is not implemented"
        )

    # compute rotational matrix elements of three-j symbol contracted with
    #   Cartesian-to-spherical tensor transformation matrix
    jktau_list1, jktau_list2, rot_me = threej_wang(rank, j1, j2, linear=linear)
    # rot_me[omega].shape = (2*j1+1, 2*j2+1, ncart)

    h5_1 = h5py.File(f"h2s_coefficients_pmax{pmax}_j{j1}.h5", "r")
    h5_2 = h5py.File(f"h2s_coefficients_pmax{pmax}_j{j2}.h5", "r")

    res = {}

    for sym1 in h5_1["energies"].keys():
        enr1 = h5_1["energies"][sym1][:]
        coefs1 = h5_1["coefficients"][sym1][:]
        vind1 = h5_1["vib-indices"][sym1][:]
        rind1 = h5_1["rot-indices"][sym1][:]
        qua1 = np.array(
            [elem[0].decode("utf-8").split(",") for elem in h5_1["quanta"][sym1][:]]
        )

        if state_ind_list1 is not None:
            if sym1 in state_ind_list1:
                ind = state_ind_list1[sym1]
                enr1 = enr1[ind]
                coefs1 = coefs1[:, ind]
            else:
                continue

        for sym2 in h5_2["energies"].keys():
            enr2 = h5_2["energies"][sym2][:]
            coefs2 = h5_2["coefficients"][sym2][:]
            vind2 = h5_2["vib-indices"][sym2][:]
            rind2 = h5_2["rot-indices"][sym2][:]
            qua2 = np.array(
                [elem[0].decode("utf-8").split(",") for elem in h5_2["quanta"][sym2][:]]
            )

            if state_ind_list2 is not None:
                if sym2 in state_ind_list2:
                    ind = state_ind_list2[sym2]
                    enr2 = enr2[ind]
                    coefs2 = coefs2[:, ind]
                else:
                    continue

            me = _matelem(vind1, vind2, rind1, rind2, coefs1, coefs2)
            if np.count_nonzero(me) > 0:
                nstates2 = np.prod(me.shape[:2])
                res[(sym1, sym2)] = csr_matrix(me.reshape(nstates2, -1))

    return res

# %% [markdown]
# Using the functions above, compute matrix elements of spin-rotation tensors for $J=50..60$ and lowest 1000 rovibrational states for each symmetry, and store matrix elements in files.

# %%
pmax = 20
rank = 2

min_J = 50
max_J = 60

state_ind_list = {sym: np.arange(1000) for sym in C2V_IRREPS}

# read vibrational matrix elements of spin-rotation tensors

with h5py.File(f"h2s_vibme_pmax{pmax}.h5", "r") as h5:
    sr_h1_vib = h5["spin-rotation"]["h1"][:]
    sr_h2_vib = h5["spin-rotation"]["h2"][:]

# compute rovibrational matrix elements and store them in file

with h5py.File(f"h2s_spinrot_enr_pmax{pmax}.h5", "w") as h5:
    for J in range(min_J, max_J + 1):
        enr, qua = rovib_states(J, state_ind_list=state_ind_list)
        print(
            f"store energies for J = {J}, no. states = {[(sym, len(state_ind_list[sym])) for sym in state_ind_list]}"
        )
        for sym in enr:
            qua_str = [",".join(elem) for elem in qua[sym]]
            max_len = max([len(elem) for elem in qua_str])
            qua_ascii = [elem.encode("ascii", "ignore") for elem in qua_str]
            h5.create_dataset(f"energies/{J}/{sym}", data=enr[sym])
            h5.create_dataset(
                f"quanta/{J}/{sym}", (len(qua_ascii), 1), f"S{max_len}", data=qua_ascii
            )

for J1 in range(min_J, max_J + 1):
    for J2 in range(min_J, max_J + 1):
        dJ = abs(J1 - J2)
        if dJ > 2:
            continue

        sr1_me = tensor_rovib_me(
            rank,
            J1,
            J2,
            sr_h1_vib,
            state_ind_list1=state_ind_list,
            state_ind_list2=state_ind_list,
            tol=1e-3,
        )  # kHz units

        sr2_me = tensor_rovib_me(
            rank,
            J1,
            J2,
            sr_h2_vib,
            state_ind_list1=state_ind_list,
            state_ind_list2=state_ind_list,
            tol=1e-3,
        )

        if sr1_me or sr2_me:
            print(f"store matrix elements for J1 = {J1} J2 = {J2}, delta J = {dJ}")
            with h5py.File(f"h2s_spinrot_me_pmax{pmax}_j{J1}_j{J2}.h5", "w") as h5:
                for i, sr in enumerate((sr1_me, sr2_me)):
                    for (sym1, sym2), me in sr.items():
                        print(
                            f"n = {i}, sym = {(sym1, sym2)}, no. elements = {len(me.data)}  "
                            + f"{round(len(me.data)/np.prod(me.shape)*100,3)}%"
                        )
                        h5.create_dataset(f"h{i+1}/{sym1}/{sym2}/data", data=me.data)
                        h5.create_dataset(
                            f"h{i+1}/{sym1}/{sym2}/indices", data=me.indices
                        )
                        h5.create_dataset(
                            f"h{i+1}/{sym1}/{sym2}/indptr", data=me.indptr
                        )
                        h5.create_dataset(f"h{i+1}/{sym1}/{sym2}/shape", data=me.shape)
# Out:
# store energies for J = 50, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 51, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 52, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 53, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 54, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 55, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 56, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 57, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 58, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 59, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store energies for J = 60, no. states = [('A1', 1000), ('A2', 1000), ('B1', 1000), ('B2', 1000)]
# store matrix elements for J1 = 50 J2 = 50, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 87757  2.925%
# n = 0, sym = ('A1', 'B2'), no. elements = 259974  8.666%
# n = 0, sym = ('A2', 'A2'), no. elements = 82431  2.748%
# n = 0, sym = ('A2', 'B1'), no. elements = 251583  8.386%
# n = 0, sym = ('B1', 'A2'), no. elements = 251583  8.386%
# n = 0, sym = ('B1', 'B1'), no. elements = 82265  2.742%
# n = 0, sym = ('B2', 'A1'), no. elements = 259974  8.666%
# n = 0, sym = ('B2', 'B2'), no. elements = 88392  2.946%
# n = 1, sym = ('A1', 'A1'), no. elements = 87757  2.925%
# n = 1, sym = ('A1', 'B2'), no. elements = 259974  8.666%
# n = 1, sym = ('A2', 'A2'), no. elements = 82431  2.748%
# n = 1, sym = ('A2', 'B1'), no. elements = 251583  8.386%
# n = 1, sym = ('B1', 'A2'), no. elements = 251583  8.386%
# n = 1, sym = ('B1', 'B1'), no. elements = 82265  2.742%
# n = 1, sym = ('B2', 'A1'), no. elements = 259974  8.666%
# n = 1, sym = ('B2', 'B2'), no. elements = 88392  2.946%
# store matrix elements for J1 = 50 J2 = 51, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 82600  2.753%
# n = 0, sym = ('A1', 'B2'), no. elements = 278599  9.287%
# n = 0, sym = ('A2', 'A2'), no. elements = 80750  2.692%
# n = 0, sym = ('A2', 'B1'), no. elements = 273786  9.126%
# n = 0, sym = ('B1', 'A2'), no. elements = 271900  9.063%
# n = 0, sym = ('B1', 'B1'), no. elements = 81222  2.707%
# n = 0, sym = ('B2', 'A1'), no. elements = 279793  9.326%
# n = 0, sym = ('B2', 'B2'), no. elements = 83125  2.771%
# n = 1, sym = ('A1', 'A1'), no. elements = 82600  2.753%
# n = 1, sym = ('A1', 'B2'), no. elements = 278599  9.287%
# n = 1, sym = ('A2', 'A2'), no. elements = 80750  2.692%
# n = 1, sym = ('A2', 'B1'), no. elements = 273786  9.126%
# n = 1, sym = ('B1', 'A2'), no. elements = 271900  9.063%
# n = 1, sym = ('B1', 'B1'), no. elements = 81222  2.707%
# n = 1, sym = ('B2', 'A1'), no. elements = 279793  9.326%
# n = 1, sym = ('B2', 'B2'), no. elements = 83125  2.771%
# store matrix elements for J1 = 50 J2 = 52, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 83449  2.782%
# n = 0, sym = ('A1', 'B2'), no. elements = 277037  9.235%
# n = 0, sym = ('A2', 'A2'), no. elements = 75214  2.507%
# n = 0, sym = ('A2', 'B1'), no. elements = 261868  8.729%
# n = 0, sym = ('B1', 'A2'), no. elements = 263853  8.795%
# n = 0, sym = ('B1', 'B1'), no. elements = 75260  2.509%
# n = 0, sym = ('B2', 'A1'), no. elements = 277425  9.248%
# n = 0, sym = ('B2', 'B2'), no. elements = 84382  2.813%
# n = 1, sym = ('A1', 'A1'), no. elements = 83449  2.782%
# n = 1, sym = ('A1', 'B2'), no. elements = 277037  9.235%
# n = 1, sym = ('A2', 'A2'), no. elements = 75214  2.507%
# n = 1, sym = ('A2', 'B1'), no. elements = 261868  8.729%
# n = 1, sym = ('B1', 'A2'), no. elements = 263853  8.795%
# n = 1, sym = ('B1', 'B1'), no. elements = 75260  2.509%
# n = 1, sym = ('B2', 'A1'), no. elements = 277425  9.248%
# n = 1, sym = ('B2', 'B2'), no. elements = 84382  2.813%
# store matrix elements for J1 = 51 J2 = 50, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 82600  2.753%
# n = 0, sym = ('A1', 'B2'), no. elements = 279793  9.326%
# n = 0, sym = ('A2', 'A2'), no. elements = 80750  2.692%
# n = 0, sym = ('A2', 'B1'), no. elements = 271900  9.063%
# n = 0, sym = ('B1', 'A2'), no. elements = 273786  9.126%
# n = 0, sym = ('B1', 'B1'), no. elements = 81222  2.707%
# n = 0, sym = ('B2', 'A1'), no. elements = 278599  9.287%
# n = 0, sym = ('B2', 'B2'), no. elements = 83125  2.771%
# n = 1, sym = ('A1', 'A1'), no. elements = 82600  2.753%
# n = 1, sym = ('A1', 'B2'), no. elements = 279793  9.326%
# n = 1, sym = ('A2', 'A2'), no. elements = 80750  2.692%
# n = 1, sym = ('A2', 'B1'), no. elements = 271900  9.063%
# n = 1, sym = ('B1', 'A2'), no. elements = 273786  9.126%
# n = 1, sym = ('B1', 'B1'), no. elements = 81222  2.707%
# n = 1, sym = ('B2', 'A1'), no. elements = 278599  9.287%
# n = 1, sym = ('B2', 'B2'), no. elements = 83125  2.771%
# store matrix elements for J1 = 51 J2 = 51, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 82868  2.762%
# n = 0, sym = ('A1', 'B2'), no. elements = 253846  8.462%
# n = 0, sym = ('A2', 'A2'), no. elements = 87462  2.915%
# n = 0, sym = ('A2', 'B1'), no. elements = 259619  8.654%
# n = 0, sym = ('B1', 'A2'), no. elements = 259619  8.654%
# n = 0, sym = ('B1', 'B1'), no. elements = 88550  2.952%
# n = 0, sym = ('B2', 'A1'), no. elements = 253846  8.462%
# n = 0, sym = ('B2', 'B2'), no. elements = 82828  2.761%
# n = 1, sym = ('A1', 'A1'), no. elements = 82868  2.762%
# n = 1, sym = ('A1', 'B2'), no. elements = 253846  8.462%
# n = 1, sym = ('A2', 'A2'), no. elements = 87462  2.915%
# n = 1, sym = ('A2', 'B1'), no. elements = 259619  8.654%
# n = 1, sym = ('B1', 'A2'), no. elements = 259619  8.654%
# n = 1, sym = ('B1', 'B1'), no. elements = 88550  2.952%
# n = 1, sym = ('B2', 'A1'), no. elements = 253846  8.462%
# n = 1, sym = ('B2', 'B2'), no. elements = 82828  2.761%
# store matrix elements for J1 = 51 J2 = 52, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 82132  2.738%
# n = 0, sym = ('A1', 'B2'), no. elements = 278575  9.286%
# n = 0, sym = ('A2', 'A2'), no. elements = 82887  2.763%
# n = 0, sym = ('A2', 'B1'), no. elements = 279088  9.303%
# n = 0, sym = ('B1', 'A2'), no. elements = 281816  9.394%
# n = 0, sym = ('B1', 'B1'), no. elements = 83038  2.768%
# n = 0, sym = ('B2', 'A1'), no. elements = 277598  9.253%
# n = 0, sym = ('B2', 'B2'), no. elements = 82517  2.751%
# n = 1, sym = ('A1', 'A1'), no. elements = 82132  2.738%
# n = 1, sym = ('A1', 'B2'), no. elements = 278575  9.286%
# n = 1, sym = ('A2', 'A2'), no. elements = 82887  2.763%
# n = 1, sym = ('A2', 'B1'), no. elements = 279088  9.303%
# n = 1, sym = ('B1', 'A2'), no. elements = 281816  9.394%
# n = 1, sym = ('B1', 'B1'), no. elements = 83038  2.768%
# n = 1, sym = ('B2', 'A1'), no. elements = 277598  9.253%
# n = 1, sym = ('B2', 'B2'), no. elements = 82517  2.751%
# store matrix elements for J1 = 51 J2 = 53, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 76302  2.543%
# n = 0, sym = ('A1', 'B2'), no. elements = 269474  8.982%
# n = 0, sym = ('A2', 'A2'), no. elements = 84203  2.807%
# n = 0, sym = ('A2', 'B1'), no. elements = 278821  9.294%
# n = 0, sym = ('B1', 'A2'), no. elements = 281698  9.39%
# n = 0, sym = ('B1', 'B1'), no. elements = 83875  2.796%
# n = 0, sym = ('B2', 'A1'), no. elements = 268265  8.942%
# n = 0, sym = ('B2', 'B2'), no. elements = 76143  2.538%
# n = 1, sym = ('A1', 'A1'), no. elements = 76302  2.543%
# n = 1, sym = ('A1', 'B2'), no. elements = 269474  8.982%
# n = 1, sym = ('A2', 'A2'), no. elements = 84203  2.807%
# n = 1, sym = ('A2', 'B1'), no. elements = 278821  9.294%
# n = 1, sym = ('B1', 'A2'), no. elements = 281698  9.39%
# n = 1, sym = ('B1', 'B1'), no. elements = 83875  2.796%
# n = 1, sym = ('B2', 'A1'), no. elements = 268265  8.942%
# n = 1, sym = ('B2', 'B2'), no. elements = 76143  2.538%
# store matrix elements for J1 = 52 J2 = 50, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 83449  2.782%
# n = 0, sym = ('A1', 'B2'), no. elements = 277425  9.248%
# n = 0, sym = ('A2', 'A2'), no. elements = 75214  2.507%
# n = 0, sym = ('A2', 'B1'), no. elements = 263853  8.795%
# n = 0, sym = ('B1', 'A2'), no. elements = 261868  8.729%
# n = 0, sym = ('B1', 'B1'), no. elements = 75260  2.509%
# n = 0, sym = ('B2', 'A1'), no. elements = 277037  9.235%
# n = 0, sym = ('B2', 'B2'), no. elements = 84382  2.813%
# n = 1, sym = ('A1', 'A1'), no. elements = 83449  2.782%
# n = 1, sym = ('A1', 'B2'), no. elements = 277425  9.248%
# n = 1, sym = ('A2', 'A2'), no. elements = 75214  2.507%
# n = 1, sym = ('A2', 'B1'), no. elements = 263853  8.795%
# n = 1, sym = ('B1', 'A2'), no. elements = 261868  8.729%
# n = 1, sym = ('B1', 'B1'), no. elements = 75260  2.509%
# n = 1, sym = ('B2', 'A1'), no. elements = 277037  9.235%
# n = 1, sym = ('B2', 'B2'), no. elements = 84382  2.813%
# store matrix elements for J1 = 52 J2 = 51, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 82132  2.738%
# n = 0, sym = ('A1', 'B2'), no. elements = 277598  9.253%
# n = 0, sym = ('A2', 'A2'), no. elements = 82887  2.763%
# n = 0, sym = ('A2', 'B1'), no. elements = 281816  9.394%
# n = 0, sym = ('B1', 'A2'), no. elements = 279088  9.303%
# n = 0, sym = ('B1', 'B1'), no. elements = 83038  2.768%
# n = 0, sym = ('B2', 'A1'), no. elements = 278575  9.286%
# n = 0, sym = ('B2', 'B2'), no. elements = 82517  2.751%
# n = 1, sym = ('A1', 'A1'), no. elements = 82132  2.738%
# n = 1, sym = ('A1', 'B2'), no. elements = 277598  9.253%
# n = 1, sym = ('A2', 'A2'), no. elements = 82887  2.763%
# n = 1, sym = ('A2', 'B1'), no. elements = 281816  9.394%
# n = 1, sym = ('B1', 'A2'), no. elements = 279088  9.303%
# n = 1, sym = ('B1', 'B1'), no. elements = 83038  2.768%
# n = 1, sym = ('B2', 'A1'), no. elements = 278575  9.286%
# n = 1, sym = ('B2', 'B2'), no. elements = 82517  2.751%
# store matrix elements for J1 = 52 J2 = 52, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 90026  3.001%
# n = 0, sym = ('A1', 'B2'), no. elements = 265891  8.863%
# n = 0, sym = ('A2', 'A2'), no. elements = 83954  2.798%
# n = 0, sym = ('A2', 'B1'), no. elements = 255963  8.532%
# n = 0, sym = ('B1', 'A2'), no. elements = 255963  8.532%
# n = 0, sym = ('B1', 'B1'), no. elements = 83320  2.777%
# n = 0, sym = ('B2', 'A1'), no. elements = 265891  8.863%
# n = 0, sym = ('B2', 'B2'), no. elements = 90638  3.021%
# n = 1, sym = ('A1', 'A1'), no. elements = 90026  3.001%
# n = 1, sym = ('A1', 'B2'), no. elements = 265891  8.863%
# n = 1, sym = ('A2', 'A2'), no. elements = 83954  2.798%
# n = 1, sym = ('A2', 'B1'), no. elements = 255963  8.532%
# n = 1, sym = ('B1', 'A2'), no. elements = 255963  8.532%
# n = 1, sym = ('B1', 'B1'), no. elements = 83320  2.777%
# n = 1, sym = ('B2', 'A1'), no. elements = 265891  8.863%
# n = 1, sym = ('B2', 'B2'), no. elements = 90638  3.021%
# store matrix elements for J1 = 52 J2 = 53, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 84065  2.802%
# n = 0, sym = ('A1', 'B2'), no. elements = 287259  9.575%
# n = 0, sym = ('A2', 'A2'), no. elements = 83536  2.785%
# n = 0, sym = ('A2', 'B1'), no. elements = 281680  9.389%
# n = 0, sym = ('B1', 'A2'), no. elements = 281810  9.394%
# n = 0, sym = ('B1', 'B1'), no. elements = 82760  2.759%
# n = 0, sym = ('B2', 'A1'), no. elements = 287148  9.572%
# n = 0, sym = ('B2', 'B2'), no. elements = 85011  2.834%
# n = 1, sym = ('A1', 'A1'), no. elements = 84065  2.802%
# n = 1, sym = ('A1', 'B2'), no. elements = 287259  9.575%
# n = 1, sym = ('A2', 'A2'), no. elements = 83536  2.785%
# n = 1, sym = ('A2', 'B1'), no. elements = 281680  9.389%
# n = 1, sym = ('B1', 'A2'), no. elements = 281810  9.394%
# n = 1, sym = ('B1', 'B1'), no. elements = 82760  2.759%
# n = 1, sym = ('B2', 'A1'), no. elements = 287148  9.572%
# n = 1, sym = ('B2', 'B2'), no. elements = 85011  2.834%
# store matrix elements for J1 = 52 J2 = 54, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 86098  2.87%
# n = 0, sym = ('A1', 'B2'), no. elements = 289405  9.647%
# n = 0, sym = ('A2', 'A2'), no. elements = 77544  2.585%
# n = 0, sym = ('A2', 'B1'), no. elements = 276621  9.221%
# n = 0, sym = ('B1', 'A2'), no. elements = 274123  9.137%
# n = 0, sym = ('B1', 'B1'), no. elements = 78167  2.606%
# n = 0, sym = ('B2', 'A1'), no. elements = 288680  9.623%
# n = 0, sym = ('B2', 'B2'), no. elements = 87236  2.908%
# n = 1, sym = ('A1', 'A1'), no. elements = 86098  2.87%
# n = 1, sym = ('A1', 'B2'), no. elements = 289405  9.647%
# n = 1, sym = ('A2', 'A2'), no. elements = 77544  2.585%
# n = 1, sym = ('A2', 'B1'), no. elements = 276621  9.221%
# n = 1, sym = ('B1', 'A2'), no. elements = 274123  9.137%
# n = 1, sym = ('B1', 'B1'), no. elements = 78167  2.606%
# n = 1, sym = ('B2', 'A1'), no. elements = 288680  9.623%
# n = 1, sym = ('B2', 'B2'), no. elements = 87236  2.908%
# store matrix elements for J1 = 53 J2 = 51, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 76302  2.543%
# n = 0, sym = ('A1', 'B2'), no. elements = 268265  8.942%
# n = 0, sym = ('A2', 'A2'), no. elements = 84203  2.807%
# n = 0, sym = ('A2', 'B1'), no. elements = 281698  9.39%
# n = 0, sym = ('B1', 'A2'), no. elements = 278821  9.294%
# n = 0, sym = ('B1', 'B1'), no. elements = 83875  2.796%
# n = 0, sym = ('B2', 'A1'), no. elements = 269474  8.982%
# n = 0, sym = ('B2', 'B2'), no. elements = 76143  2.538%
# n = 1, sym = ('A1', 'A1'), no. elements = 76302  2.543%
# n = 1, sym = ('A1', 'B2'), no. elements = 268265  8.942%
# n = 1, sym = ('A2', 'A2'), no. elements = 84203  2.807%
# n = 1, sym = ('A2', 'B1'), no. elements = 281698  9.39%
# n = 1, sym = ('B1', 'A2'), no. elements = 278821  9.294%
# n = 1, sym = ('B1', 'B1'), no. elements = 83875  2.796%
# n = 1, sym = ('B2', 'A1'), no. elements = 269474  8.982%
# n = 1, sym = ('B2', 'B2'), no. elements = 76143  2.538%
# store matrix elements for J1 = 53 J2 = 52, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 84065  2.802%
# n = 0, sym = ('A1', 'B2'), no. elements = 287148  9.572%
# n = 0, sym = ('A2', 'A2'), no. elements = 83536  2.785%
# n = 0, sym = ('A2', 'B1'), no. elements = 281810  9.394%
# n = 0, sym = ('B1', 'A2'), no. elements = 281680  9.389%
# n = 0, sym = ('B1', 'B1'), no. elements = 82760  2.759%
# n = 0, sym = ('B2', 'A1'), no. elements = 287259  9.575%
# n = 0, sym = ('B2', 'B2'), no. elements = 85011  2.834%
# n = 1, sym = ('A1', 'A1'), no. elements = 84065  2.802%
# n = 1, sym = ('A1', 'B2'), no. elements = 287148  9.572%
# n = 1, sym = ('A2', 'A2'), no. elements = 83536  2.785%
# n = 1, sym = ('A2', 'B1'), no. elements = 281810  9.394%
# n = 1, sym = ('B1', 'A2'), no. elements = 281680  9.389%
# n = 1, sym = ('B1', 'B1'), no. elements = 82760  2.759%
# n = 1, sym = ('B2', 'A1'), no. elements = 287259  9.575%
# n = 1, sym = ('B2', 'B2'), no. elements = 85011  2.834%
# store matrix elements for J1 = 53 J2 = 53, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 85745  2.858%
# n = 0, sym = ('A1', 'B2'), no. elements = 261239  8.708%
# n = 0, sym = ('A2', 'A2'), no. elements = 91099  3.037%
# n = 0, sym = ('A2', 'B1'), no. elements = 267661  8.922%
# n = 0, sym = ('B1', 'A2'), no. elements = 267661  8.922%
# n = 0, sym = ('B1', 'B1'), no. elements = 90817  3.027%
# n = 0, sym = ('B2', 'A1'), no. elements = 261239  8.708%
# n = 0, sym = ('B2', 'B2'), no. elements = 86076  2.869%
# n = 1, sym = ('A1', 'A1'), no. elements = 85745  2.858%
# n = 1, sym = ('A1', 'B2'), no. elements = 261239  8.708%
# n = 1, sym = ('A2', 'A2'), no. elements = 91099  3.037%
# n = 1, sym = ('A2', 'B1'), no. elements = 267661  8.922%
# n = 1, sym = ('B1', 'A2'), no. elements = 267661  8.922%
# n = 1, sym = ('B1', 'B1'), no. elements = 90817  3.027%
# n = 1, sym = ('B2', 'A1'), no. elements = 261239  8.708%
# n = 1, sym = ('B2', 'B2'), no. elements = 86076  2.869%
# store matrix elements for J1 = 53 J2 = 54, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 84158  2.805%
# n = 0, sym = ('A1', 'B2'), no. elements = 289195  9.64%
# n = 0, sym = ('A2', 'A2'), no. elements = 85544  2.851%
# n = 0, sym = ('A2', 'B1'), no. elements = 292641  9.755%
# n = 0, sym = ('B1', 'A2'), no. elements = 289778  9.659%
# n = 0, sym = ('B1', 'B1'), no. elements = 85832  2.861%
# n = 0, sym = ('B2', 'A1'), no. elements = 287949  9.598%
# n = 0, sym = ('B2', 'B2'), no. elements = 85228  2.841%
# n = 1, sym = ('A1', 'A1'), no. elements = 84158  2.805%
# n = 1, sym = ('A1', 'B2'), no. elements = 289195  9.64%
# n = 1, sym = ('A2', 'A2'), no. elements = 85544  2.851%
# n = 1, sym = ('A2', 'B1'), no. elements = 292641  9.755%
# n = 1, sym = ('B1', 'A2'), no. elements = 289778  9.659%
# n = 1, sym = ('B1', 'B1'), no. elements = 85832  2.861%
# n = 1, sym = ('B2', 'A1'), no. elements = 287949  9.598%
# n = 1, sym = ('B2', 'B2'), no. elements = 85228  2.841%
# store matrix elements for J1 = 53 J2 = 55, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 79834  2.661%
# n = 0, sym = ('A1', 'B2'), no. elements = 279735  9.324%
# n = 0, sym = ('A2', 'A2'), no. elements = 87636  2.921%
# n = 0, sym = ('A2', 'B1'), no. elements = 294586  9.82%
# n = 0, sym = ('B1', 'A2'), no. elements = 293755  9.792%
# n = 0, sym = ('B1', 'B1'), no. elements = 87054  2.902%
# n = 0, sym = ('B2', 'A1'), no. elements = 282350  9.412%
# n = 0, sym = ('B2', 'B2'), no. elements = 78911  2.63%
# n = 1, sym = ('A1', 'A1'), no. elements = 79834  2.661%
# n = 1, sym = ('A1', 'B2'), no. elements = 279735  9.324%
# n = 1, sym = ('A2', 'A2'), no. elements = 87636  2.921%
# n = 1, sym = ('A2', 'B1'), no. elements = 294586  9.82%
# n = 1, sym = ('B1', 'A2'), no. elements = 293755  9.792%
# n = 1, sym = ('B1', 'B1'), no. elements = 87054  2.902%
# n = 1, sym = ('B2', 'A1'), no. elements = 282350  9.412%
# n = 1, sym = ('B2', 'B2'), no. elements = 78911  2.63%
# store matrix elements for J1 = 54 J2 = 52, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 86098  2.87%
# n = 0, sym = ('A1', 'B2'), no. elements = 288680  9.623%
# n = 0, sym = ('A2', 'A2'), no. elements = 77544  2.585%
# n = 0, sym = ('A2', 'B1'), no. elements = 274123  9.137%
# n = 0, sym = ('B1', 'A2'), no. elements = 276621  9.221%
# n = 0, sym = ('B1', 'B1'), no. elements = 78167  2.606%
# n = 0, sym = ('B2', 'A1'), no. elements = 289405  9.647%
# n = 0, sym = ('B2', 'B2'), no. elements = 87236  2.908%
# n = 1, sym = ('A1', 'A1'), no. elements = 86098  2.87%
# n = 1, sym = ('A1', 'B2'), no. elements = 288680  9.623%
# n = 1, sym = ('A2', 'A2'), no. elements = 77544  2.585%
# n = 1, sym = ('A2', 'B1'), no. elements = 274123  9.137%
# n = 1, sym = ('B1', 'A2'), no. elements = 276621  9.221%
# n = 1, sym = ('B1', 'B1'), no. elements = 78167  2.606%
# n = 1, sym = ('B2', 'A1'), no. elements = 289405  9.647%
# n = 1, sym = ('B2', 'B2'), no. elements = 87236  2.908%
# store matrix elements for J1 = 54 J2 = 53, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 84158  2.805%
# n = 0, sym = ('A1', 'B2'), no. elements = 287949  9.598%
# n = 0, sym = ('A2', 'A2'), no. elements = 85544  2.851%
# n = 0, sym = ('A2', 'B1'), no. elements = 289778  9.659%
# n = 0, sym = ('B1', 'A2'), no. elements = 292641  9.755%
# n = 0, sym = ('B1', 'B1'), no. elements = 85832  2.861%
# n = 0, sym = ('B2', 'A1'), no. elements = 289195  9.64%
# n = 0, sym = ('B2', 'B2'), no. elements = 85228  2.841%
# n = 1, sym = ('A1', 'A1'), no. elements = 84158  2.805%
# n = 1, sym = ('A1', 'B2'), no. elements = 287949  9.598%
# n = 1, sym = ('A2', 'A2'), no. elements = 85544  2.851%
# n = 1, sym = ('A2', 'B1'), no. elements = 289778  9.659%
# n = 1, sym = ('B1', 'A2'), no. elements = 292641  9.755%
# n = 1, sym = ('B1', 'B1'), no. elements = 85832  2.861%
# n = 1, sym = ('B2', 'A1'), no. elements = 289195  9.64%
# n = 1, sym = ('B2', 'B2'), no. elements = 85228  2.841%
# store matrix elements for J1 = 54 J2 = 54, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 93209  3.107%
# n = 0, sym = ('A1', 'B2'), no. elements = 274227  9.141%
# n = 0, sym = ('A2', 'A2'), no. elements = 87721  2.924%
# n = 0, sym = ('A2', 'B1'), no. elements = 266769  8.892%
# n = 0, sym = ('B1', 'A2'), no. elements = 266769  8.892%
# n = 0, sym = ('B1', 'B1'), no. elements = 88971  2.966%
# n = 0, sym = ('B2', 'A1'), no. elements = 274227  9.141%
# n = 0, sym = ('B2', 'B2'), no. elements = 94195  3.14%
# n = 1, sym = ('A1', 'A1'), no. elements = 93209  3.107%
# n = 1, sym = ('A1', 'B2'), no. elements = 274227  9.141%
# n = 1, sym = ('A2', 'A2'), no. elements = 87721  2.924%
# n = 1, sym = ('A2', 'B1'), no. elements = 266769  8.892%
# n = 1, sym = ('B1', 'A2'), no. elements = 266769  8.892%
# n = 1, sym = ('B1', 'B1'), no. elements = 88971  2.966%
# n = 1, sym = ('B2', 'A1'), no. elements = 274227  9.141%
# n = 1, sym = ('B2', 'B2'), no. elements = 94195  3.14%
# store matrix elements for J1 = 54 J2 = 55, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 87710  2.924%
# n = 0, sym = ('A1', 'B2'), no. elements = 294262  9.809%
# n = 0, sym = ('A2', 'A2'), no. elements = 85577  2.853%
# n = 0, sym = ('A2', 'B1'), no. elements = 292262  9.742%
# n = 0, sym = ('B1', 'A2'), no. elements = 293359  9.779%
# n = 0, sym = ('B1', 'B1'), no. elements = 85965  2.866%
# n = 0, sym = ('B2', 'A1'), no. elements = 298048  9.935%
# n = 0, sym = ('B2', 'B2'), no. elements = 87728  2.924%
# n = 1, sym = ('A1', 'A1'), no. elements = 87710  2.924%
# n = 1, sym = ('A1', 'B2'), no. elements = 294262  9.809%
# n = 1, sym = ('A2', 'A2'), no. elements = 85577  2.853%
# n = 1, sym = ('A2', 'B1'), no. elements = 292262  9.742%
# n = 1, sym = ('B1', 'A2'), no. elements = 293359  9.779%
# n = 1, sym = ('B1', 'B1'), no. elements = 85965  2.866%
# n = 1, sym = ('B2', 'A1'), no. elements = 298048  9.935%
# n = 1, sym = ('B2', 'B2'), no. elements = 87728  2.924%
# store matrix elements for J1 = 54 J2 = 56, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 87812  2.927%
# n = 0, sym = ('A1', 'B2'), no. elements = 301311  10.044%
# n = 0, sym = ('A2', 'A2'), no. elements = 80716  2.691%
# n = 0, sym = ('A2', 'B1'), no. elements = 291169  9.706%
# n = 0, sym = ('B1', 'A2'), no. elements = 290300  9.677%
# n = 0, sym = ('B1', 'B1'), no. elements = 82248  2.742%
# n = 0, sym = ('B2', 'A1'), no. elements = 300115  10.004%
# n = 0, sym = ('B2', 'B2'), no. elements = 89323  2.977%
# n = 1, sym = ('A1', 'A1'), no. elements = 87812  2.927%
# n = 1, sym = ('A1', 'B2'), no. elements = 301311  10.044%
# n = 1, sym = ('A2', 'A2'), no. elements = 80716  2.691%
# n = 1, sym = ('A2', 'B1'), no. elements = 291169  9.706%
# n = 1, sym = ('B1', 'A2'), no. elements = 290300  9.677%
# n = 1, sym = ('B1', 'B1'), no. elements = 82248  2.742%
# n = 1, sym = ('B2', 'A1'), no. elements = 300115  10.004%
# n = 1, sym = ('B2', 'B2'), no. elements = 89323  2.977%
# store matrix elements for J1 = 55 J2 = 53, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 79834  2.661%
# n = 0, sym = ('A1', 'B2'), no. elements = 282350  9.412%
# n = 0, sym = ('A2', 'A2'), no. elements = 87636  2.921%
# n = 0, sym = ('A2', 'B1'), no. elements = 293755  9.792%
# n = 0, sym = ('B1', 'A2'), no. elements = 294586  9.82%
# n = 0, sym = ('B1', 'B1'), no. elements = 87054  2.902%
# n = 0, sym = ('B2', 'A1'), no. elements = 279735  9.324%
# n = 0, sym = ('B2', 'B2'), no. elements = 78911  2.63%
# n = 1, sym = ('A1', 'A1'), no. elements = 79834  2.661%
# n = 1, sym = ('A1', 'B2'), no. elements = 282350  9.412%
# n = 1, sym = ('A2', 'A2'), no. elements = 87636  2.921%
# n = 1, sym = ('A2', 'B1'), no. elements = 293755  9.792%
# n = 1, sym = ('B1', 'A2'), no. elements = 294586  9.82%
# n = 1, sym = ('B1', 'B1'), no. elements = 87054  2.902%
# n = 1, sym = ('B2', 'A1'), no. elements = 279735  9.324%
# n = 1, sym = ('B2', 'B2'), no. elements = 78911  2.63%
# store matrix elements for J1 = 55 J2 = 54, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 87710  2.924%
# n = 0, sym = ('A1', 'B2'), no. elements = 298048  9.935%
# n = 0, sym = ('A2', 'A2'), no. elements = 85577  2.853%
# n = 0, sym = ('A2', 'B1'), no. elements = 293359  9.779%
# n = 0, sym = ('B1', 'A2'), no. elements = 292262  9.742%
# n = 0, sym = ('B1', 'B1'), no. elements = 85965  2.866%
# n = 0, sym = ('B2', 'A1'), no. elements = 294262  9.809%
# n = 0, sym = ('B2', 'B2'), no. elements = 87728  2.924%
# n = 1, sym = ('A1', 'A1'), no. elements = 87710  2.924%
# n = 1, sym = ('A1', 'B2'), no. elements = 298048  9.935%
# n = 1, sym = ('A2', 'A2'), no. elements = 85577  2.853%
# n = 1, sym = ('A2', 'B1'), no. elements = 293359  9.779%
# n = 1, sym = ('B1', 'A2'), no. elements = 292262  9.742%
# n = 1, sym = ('B1', 'B1'), no. elements = 85965  2.866%
# n = 1, sym = ('B2', 'A1'), no. elements = 294262  9.809%
# n = 1, sym = ('B2', 'B2'), no. elements = 87728  2.924%
# store matrix elements for J1 = 55 J2 = 55, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 90246  3.008%
# n = 0, sym = ('A1', 'B2'), no. elements = 268653  8.955%
# n = 0, sym = ('A2', 'A2'), no. elements = 93876  3.129%
# n = 0, sym = ('A2', 'B1'), no. elements = 276584  9.219%
# n = 0, sym = ('B1', 'A2'), no. elements = 276584  9.219%
# n = 0, sym = ('B1', 'B1'), no. elements = 94060  3.135%
# n = 0, sym = ('B2', 'A1'), no. elements = 268653  8.955%
# n = 0, sym = ('B2', 'B2'), no. elements = 88523  2.951%
# n = 1, sym = ('A1', 'A1'), no. elements = 90246  3.008%
# n = 1, sym = ('A1', 'B2'), no. elements = 268653  8.955%
# n = 1, sym = ('A2', 'A2'), no. elements = 93876  3.129%
# n = 1, sym = ('A2', 'B1'), no. elements = 276584  9.219%
# n = 1, sym = ('B1', 'A2'), no. elements = 276584  9.219%
# n = 1, sym = ('B1', 'B1'), no. elements = 94060  3.135%
# n = 1, sym = ('B2', 'A1'), no. elements = 268653  8.955%
# n = 1, sym = ('B2', 'B2'), no. elements = 88523  2.951%
# store matrix elements for J1 = 55 J2 = 56, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 86386  2.88%
# n = 0, sym = ('A1', 'B2'), no. elements = 296721  9.891%
# n = 0, sym = ('A2', 'A2'), no. elements = 88389  2.946%
# n = 0, sym = ('A2', 'B1'), no. elements = 304027  10.134%
# n = 0, sym = ('B1', 'A2'), no. elements = 301465  10.049%
# n = 0, sym = ('B1', 'B1'), no. elements = 89133  2.971%
# n = 0, sym = ('B2', 'A1'), no. elements = 291855  9.728%
# n = 0, sym = ('B2', 'B2'), no. elements = 86454  2.882%
# n = 1, sym = ('A1', 'A1'), no. elements = 86386  2.88%
# n = 1, sym = ('A1', 'B2'), no. elements = 296721  9.891%
# n = 1, sym = ('A2', 'A2'), no. elements = 88389  2.946%
# n = 1, sym = ('A2', 'B1'), no. elements = 304027  10.134%
# n = 1, sym = ('B1', 'A2'), no. elements = 301465  10.049%
# n = 1, sym = ('B1', 'B1'), no. elements = 89133  2.971%
# n = 1, sym = ('B2', 'A1'), no. elements = 291855  9.728%
# n = 1, sym = ('B2', 'B2'), no. elements = 86454  2.882%
# store matrix elements for J1 = 55 J2 = 57, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 83667  2.789%
# n = 0, sym = ('A1', 'B2'), no. elements = 298653  9.955%
# n = 0, sym = ('A2', 'A2'), no. elements = 90332  3.011%
# n = 0, sym = ('A2', 'B1'), no. elements = 309004  10.3%
# n = 0, sym = ('B1', 'A2'), no. elements = 307965  10.266%
# n = 0, sym = ('B1', 'B1'), no. elements = 90178  3.006%
# n = 0, sym = ('B2', 'A1'), no. elements = 296164  9.872%
# n = 0, sym = ('B2', 'B2'), no. elements = 82805  2.76%
# n = 1, sym = ('A1', 'A1'), no. elements = 83667  2.789%
# n = 1, sym = ('A1', 'B2'), no. elements = 298653  9.955%
# n = 1, sym = ('A2', 'A2'), no. elements = 90332  3.011%
# n = 1, sym = ('A2', 'B1'), no. elements = 309004  10.3%
# n = 1, sym = ('B1', 'A2'), no. elements = 307965  10.266%
# n = 1, sym = ('B1', 'B1'), no. elements = 90178  3.006%
# n = 1, sym = ('B2', 'A1'), no. elements = 296164  9.872%
# n = 1, sym = ('B2', 'B2'), no. elements = 82805  2.76%
# store matrix elements for J1 = 56 J2 = 54, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 87812  2.927%
# n = 0, sym = ('A1', 'B2'), no. elements = 300115  10.004%
# n = 0, sym = ('A2', 'A2'), no. elements = 80716  2.691%
# n = 0, sym = ('A2', 'B1'), no. elements = 290300  9.677%
# n = 0, sym = ('B1', 'A2'), no. elements = 291169  9.706%
# n = 0, sym = ('B1', 'B1'), no. elements = 82248  2.742%
# n = 0, sym = ('B2', 'A1'), no. elements = 301311  10.044%
# n = 0, sym = ('B2', 'B2'), no. elements = 89323  2.977%
# n = 1, sym = ('A1', 'A1'), no. elements = 87812  2.927%
# n = 1, sym = ('A1', 'B2'), no. elements = 300115  10.004%
# n = 1, sym = ('A2', 'A2'), no. elements = 80716  2.691%
# n = 1, sym = ('A2', 'B1'), no. elements = 290300  9.677%
# n = 1, sym = ('B1', 'A2'), no. elements = 291169  9.706%
# n = 1, sym = ('B1', 'B1'), no. elements = 82248  2.742%
# n = 1, sym = ('B2', 'A1'), no. elements = 301311  10.044%
# n = 1, sym = ('B2', 'B2'), no. elements = 89323  2.977%
# store matrix elements for J1 = 56 J2 = 55, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 86386  2.88%
# n = 0, sym = ('A1', 'B2'), no. elements = 291855  9.728%
# n = 0, sym = ('A2', 'A2'), no. elements = 88389  2.946%
# n = 0, sym = ('A2', 'B1'), no. elements = 301465  10.049%
# n = 0, sym = ('B1', 'A2'), no. elements = 304027  10.134%
# n = 0, sym = ('B1', 'B1'), no. elements = 89133  2.971%
# n = 0, sym = ('B2', 'A1'), no. elements = 296721  9.891%
# n = 0, sym = ('B2', 'B2'), no. elements = 86454  2.882%
# n = 1, sym = ('A1', 'A1'), no. elements = 86386  2.88%
# n = 1, sym = ('A1', 'B2'), no. elements = 291855  9.728%
# n = 1, sym = ('A2', 'A2'), no. elements = 88389  2.946%
# n = 1, sym = ('A2', 'B1'), no. elements = 301465  10.049%
# n = 1, sym = ('B1', 'A2'), no. elements = 304027  10.134%
# n = 1, sym = ('B1', 'B1'), no. elements = 89133  2.971%
# n = 1, sym = ('B2', 'A1'), no. elements = 296721  9.891%
# n = 1, sym = ('B2', 'B2'), no. elements = 86454  2.882%
# store matrix elements for J1 = 56 J2 = 56, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 93928  3.131%
# n = 0, sym = ('A1', 'B2'), no. elements = 277380  9.246%
# n = 0, sym = ('A2', 'A2'), no. elements = 91604  3.053%
# n = 0, sym = ('A2', 'B1'), no. elements = 278578  9.286%
# n = 0, sym = ('B1', 'A2'), no. elements = 278578  9.286%
# n = 0, sym = ('B1', 'B1'), no. elements = 93433  3.114%
# n = 0, sym = ('B2', 'A1'), no. elements = 277380  9.246%
# n = 0, sym = ('B2', 'B2'), no. elements = 95258  3.175%
# n = 1, sym = ('A1', 'A1'), no. elements = 93928  3.131%
# n = 1, sym = ('A1', 'B2'), no. elements = 277380  9.246%
# n = 1, sym = ('A2', 'A2'), no. elements = 91604  3.053%
# n = 1, sym = ('A2', 'B1'), no. elements = 278578  9.286%
# n = 1, sym = ('B1', 'A2'), no. elements = 278578  9.286%
# n = 1, sym = ('B1', 'B1'), no. elements = 93433  3.114%
# n = 1, sym = ('B2', 'A1'), no. elements = 277380  9.246%
# n = 1, sym = ('B2', 'B2'), no. elements = 95258  3.175%
# store matrix elements for J1 = 56 J2 = 57, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 90256  3.009%
# n = 0, sym = ('A1', 'B2'), no. elements = 307273  10.242%
# n = 0, sym = ('A2', 'A2'), no. elements = 88283  2.943%
# n = 0, sym = ('A2', 'B1'), no. elements = 302511  10.084%
# n = 0, sym = ('B1', 'A2'), no. elements = 304046  10.135%
# n = 0, sym = ('B1', 'B1'), no. elements = 89562  2.985%
# n = 0, sym = ('B2', 'A1'), no. elements = 310243  10.341%
# n = 0, sym = ('B2', 'B2'), no. elements = 90798  3.027%
# n = 1, sym = ('A1', 'A1'), no. elements = 90256  3.009%
# n = 1, sym = ('A1', 'B2'), no. elements = 307273  10.242%
# n = 1, sym = ('A2', 'A2'), no. elements = 88283  2.943%
# n = 1, sym = ('A2', 'B1'), no. elements = 302511  10.084%
# n = 1, sym = ('B1', 'A2'), no. elements = 304046  10.135%
# n = 1, sym = ('B1', 'B1'), no. elements = 89562  2.985%
# n = 1, sym = ('B2', 'A1'), no. elements = 310243  10.341%
# n = 1, sym = ('B2', 'B2'), no. elements = 90798  3.027%
# store matrix elements for J1 = 56 J2 = 58, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 89619  2.987%
# n = 0, sym = ('A1', 'B2'), no. elements = 310316  10.344%
# n = 0, sym = ('A2', 'A2'), no. elements = 84614  2.82%
# n = 0, sym = ('A2', 'B1'), no. elements = 305628  10.188%
# n = 0, sym = ('B1', 'A2'), no. elements = 308187  10.273%
# n = 0, sym = ('B1', 'B1'), no. elements = 85876  2.863%
# n = 0, sym = ('B2', 'A1'), no. elements = 311542  10.385%
# n = 0, sym = ('B2', 'B2'), no. elements = 90830  3.028%
# n = 1, sym = ('A1', 'A1'), no. elements = 89619  2.987%
# n = 1, sym = ('A1', 'B2'), no. elements = 310316  10.344%
# n = 1, sym = ('A2', 'A2'), no. elements = 84614  2.82%
# n = 1, sym = ('A2', 'B1'), no. elements = 305628  10.188%
# n = 1, sym = ('B1', 'A2'), no. elements = 308187  10.273%
# n = 1, sym = ('B1', 'B1'), no. elements = 85876  2.863%
# n = 1, sym = ('B2', 'A1'), no. elements = 311542  10.385%
# n = 1, sym = ('B2', 'B2'), no. elements = 90830  3.028%
# store matrix elements for J1 = 57 J2 = 55, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 83667  2.789%
# n = 0, sym = ('A1', 'B2'), no. elements = 296164  9.872%
# n = 0, sym = ('A2', 'A2'), no. elements = 90332  3.011%
# n = 0, sym = ('A2', 'B1'), no. elements = 307965  10.266%
# n = 0, sym = ('B1', 'A2'), no. elements = 309004  10.3%
# n = 0, sym = ('B1', 'B1'), no. elements = 90178  3.006%
# n = 0, sym = ('B2', 'A1'), no. elements = 298653  9.955%
# n = 0, sym = ('B2', 'B2'), no. elements = 82805  2.76%
# n = 1, sym = ('A1', 'A1'), no. elements = 83667  2.789%
# n = 1, sym = ('A1', 'B2'), no. elements = 296164  9.872%
# n = 1, sym = ('A2', 'A2'), no. elements = 90332  3.011%
# n = 1, sym = ('A2', 'B1'), no. elements = 307965  10.266%
# n = 1, sym = ('B1', 'A2'), no. elements = 309004  10.3%
# n = 1, sym = ('B1', 'B1'), no. elements = 90178  3.006%
# n = 1, sym = ('B2', 'A1'), no. elements = 298653  9.955%
# n = 1, sym = ('B2', 'B2'), no. elements = 82805  2.76%
# store matrix elements for J1 = 57 J2 = 56, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 90256  3.009%
# n = 0, sym = ('A1', 'B2'), no. elements = 310243  10.341%
# n = 0, sym = ('A2', 'A2'), no. elements = 88283  2.943%
# n = 0, sym = ('A2', 'B1'), no. elements = 304046  10.135%
# n = 0, sym = ('B1', 'A2'), no. elements = 302511  10.084%
# n = 0, sym = ('B1', 'B1'), no. elements = 89562  2.985%
# n = 0, sym = ('B2', 'A1'), no. elements = 307273  10.242%
# n = 0, sym = ('B2', 'B2'), no. elements = 90798  3.027%
# n = 1, sym = ('A1', 'A1'), no. elements = 90256  3.009%
# n = 1, sym = ('A1', 'B2'), no. elements = 310243  10.341%
# n = 1, sym = ('A2', 'A2'), no. elements = 88283  2.943%
# n = 1, sym = ('A2', 'B1'), no. elements = 304046  10.135%
# n = 1, sym = ('B1', 'A2'), no. elements = 302511  10.084%
# n = 1, sym = ('B1', 'B1'), no. elements = 89562  2.985%
# n = 1, sym = ('B2', 'A1'), no. elements = 307273  10.242%
# n = 1, sym = ('B2', 'B2'), no. elements = 90798  3.027%
# store matrix elements for J1 = 57 J2 = 57, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 96166  3.206%
# n = 0, sym = ('A1', 'B2'), no. elements = 286008  9.534%
# n = 0, sym = ('A2', 'A2'), no. elements = 96235  3.208%
# n = 0, sym = ('A2', 'B1'), no. elements = 283607  9.454%
# n = 0, sym = ('B1', 'A2'), no. elements = 283607  9.454%
# n = 0, sym = ('B1', 'B1'), no. elements = 96889  3.23%
# n = 0, sym = ('B2', 'A1'), no. elements = 286008  9.534%
# n = 0, sym = ('B2', 'B2'), no. elements = 96103  3.203%
# n = 1, sym = ('A1', 'A1'), no. elements = 96166  3.206%
# n = 1, sym = ('A1', 'B2'), no. elements = 286008  9.534%
# n = 1, sym = ('A2', 'A2'), no. elements = 96235  3.208%
# n = 1, sym = ('A2', 'B1'), no. elements = 283607  9.454%
# n = 1, sym = ('B1', 'A2'), no. elements = 283607  9.454%
# n = 1, sym = ('B1', 'B1'), no. elements = 96889  3.23%
# n = 1, sym = ('B2', 'A1'), no. elements = 286008  9.534%
# n = 1, sym = ('B2', 'B2'), no. elements = 96103  3.203%
# store matrix elements for J1 = 57 J2 = 58, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 90042  3.001%
# n = 0, sym = ('A1', 'B2'), no. elements = 309040  10.301%
# n = 0, sym = ('A2', 'A2'), no. elements = 92165  3.072%
# n = 0, sym = ('A2', 'B1'), no. elements = 314545  10.485%
# n = 0, sym = ('B1', 'A2'), no. elements = 315170  10.506%
# n = 0, sym = ('B1', 'B1'), no. elements = 92521  3.084%
# n = 0, sym = ('B2', 'A1'), no. elements = 307758  10.259%
# n = 0, sym = ('B2', 'B2'), no. elements = 90709  3.024%
# n = 1, sym = ('A1', 'A1'), no. elements = 90042  3.001%
# n = 1, sym = ('A1', 'B2'), no. elements = 309040  10.301%
# n = 1, sym = ('A2', 'A2'), no. elements = 92165  3.072%
# n = 1, sym = ('A2', 'B1'), no. elements = 314545  10.485%
# n = 1, sym = ('B1', 'A2'), no. elements = 315170  10.506%
# n = 1, sym = ('B1', 'B1'), no. elements = 92521  3.084%
# n = 1, sym = ('B2', 'A1'), no. elements = 307758  10.259%
# n = 1, sym = ('B2', 'B2'), no. elements = 90709  3.024%
# store matrix elements for J1 = 57 J2 = 59, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 87887  2.93%
# n = 0, sym = ('A1', 'B2'), no. elements = 315890  10.53%
# n = 0, sym = ('A2', 'A2'), no. elements = 91298  3.043%
# n = 0, sym = ('A2', 'B1'), no. elements = 315892  10.53%
# n = 0, sym = ('B1', 'A2'), no. elements = 316717  10.557%
# n = 0, sym = ('B1', 'B1'), no. elements = 91283  3.043%
# n = 0, sym = ('B2', 'A1'), no. elements = 316427  10.548%
# n = 0, sym = ('B2', 'B2'), no. elements = 87184  2.906%
# n = 1, sym = ('A1', 'A1'), no. elements = 87887  2.93%
# n = 1, sym = ('A1', 'B2'), no. elements = 315890  10.53%
# n = 1, sym = ('A2', 'A2'), no. elements = 91298  3.043%
# n = 1, sym = ('A2', 'B1'), no. elements = 315892  10.53%
# n = 1, sym = ('B1', 'A2'), no. elements = 316717  10.557%
# n = 1, sym = ('B1', 'B1'), no. elements = 91283  3.043%
# n = 1, sym = ('B2', 'A1'), no. elements = 316427  10.548%
# n = 1, sym = ('B2', 'B2'), no. elements = 87184  2.906%
# store matrix elements for J1 = 58 J2 = 56, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 89619  2.987%
# n = 0, sym = ('A1', 'B2'), no. elements = 311542  10.385%
# n = 0, sym = ('A2', 'A2'), no. elements = 84614  2.82%
# n = 0, sym = ('A2', 'B1'), no. elements = 308187  10.273%
# n = 0, sym = ('B1', 'A2'), no. elements = 305628  10.188%
# n = 0, sym = ('B1', 'B1'), no. elements = 85876  2.863%
# n = 0, sym = ('B2', 'A1'), no. elements = 310316  10.344%
# n = 0, sym = ('B2', 'B2'), no. elements = 90830  3.028%
# n = 1, sym = ('A1', 'A1'), no. elements = 89619  2.987%
# n = 1, sym = ('A1', 'B2'), no. elements = 311542  10.385%
# n = 1, sym = ('A2', 'A2'), no. elements = 84614  2.82%
# n = 1, sym = ('A2', 'B1'), no. elements = 308187  10.273%
# n = 1, sym = ('B1', 'A2'), no. elements = 305628  10.188%
# n = 1, sym = ('B1', 'B1'), no. elements = 85876  2.863%
# n = 1, sym = ('B2', 'A1'), no. elements = 310316  10.344%
# n = 1, sym = ('B2', 'B2'), no. elements = 90830  3.028%
# store matrix elements for J1 = 58 J2 = 57, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 90042  3.001%
# n = 0, sym = ('A1', 'B2'), no. elements = 307758  10.259%
# n = 0, sym = ('A2', 'A2'), no. elements = 92165  3.072%
# n = 0, sym = ('A2', 'B1'), no. elements = 315170  10.506%
# n = 0, sym = ('B1', 'A2'), no. elements = 314545  10.485%
# n = 0, sym = ('B1', 'B1'), no. elements = 92521  3.084%
# n = 0, sym = ('B2', 'A1'), no. elements = 309040  10.301%
# n = 0, sym = ('B2', 'B2'), no. elements = 90709  3.024%
# n = 1, sym = ('A1', 'A1'), no. elements = 90042  3.001%
# n = 1, sym = ('A1', 'B2'), no. elements = 307758  10.259%
# n = 1, sym = ('A2', 'A2'), no. elements = 92165  3.072%
# n = 1, sym = ('A2', 'B1'), no. elements = 315170  10.506%
# n = 1, sym = ('B1', 'A2'), no. elements = 314545  10.485%
# n = 1, sym = ('B1', 'B1'), no. elements = 92521  3.084%
# n = 1, sym = ('B2', 'A1'), no. elements = 309040  10.301%
# n = 1, sym = ('B2', 'B2'), no. elements = 90709  3.024%
# store matrix elements for J1 = 58 J2 = 58, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 96125  3.204%
# n = 0, sym = ('A1', 'B2'), no. elements = 283758  9.459%
# n = 0, sym = ('A2', 'A2'), no. elements = 97746  3.258%
# n = 0, sym = ('A2', 'B1'), no. elements = 289407  9.647%
# n = 0, sym = ('B1', 'A2'), no. elements = 289407  9.647%
# n = 0, sym = ('B1', 'B1'), no. elements = 97508  3.25%
# n = 0, sym = ('B2', 'A1'), no. elements = 283758  9.459%
# n = 0, sym = ('B2', 'B2'), no. elements = 97077  3.236%
# n = 1, sym = ('A1', 'A1'), no. elements = 96125  3.204%
# n = 1, sym = ('A1', 'B2'), no. elements = 283758  9.459%
# n = 1, sym = ('A2', 'A2'), no. elements = 97746  3.258%
# n = 1, sym = ('A2', 'B1'), no. elements = 289407  9.647%
# n = 1, sym = ('B1', 'A2'), no. elements = 289407  9.647%
# n = 1, sym = ('B1', 'B1'), no. elements = 97508  3.25%
# n = 1, sym = ('B2', 'A1'), no. elements = 283758  9.459%
# n = 1, sym = ('B2', 'B2'), no. elements = 97077  3.236%
# store matrix elements for J1 = 58 J2 = 59, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 93183  3.106%
# n = 0, sym = ('A1', 'B2'), no. elements = 318064  10.602%
# n = 0, sym = ('A2', 'A2'), no. elements = 91788  3.06%
# n = 0, sym = ('A2', 'B1'), no. elements = 311654  10.388%
# n = 0, sym = ('B1', 'A2'), no. elements = 311448  10.382%
# n = 0, sym = ('B1', 'B1'), no. elements = 91588  3.053%
# n = 0, sym = ('B2', 'A1'), no. elements = 319766  10.659%
# n = 0, sym = ('B2', 'B2'), no. elements = 93887  3.13%
# n = 1, sym = ('A1', 'A1'), no. elements = 93183  3.106%
# n = 1, sym = ('A1', 'B2'), no. elements = 318064  10.602%
# n = 1, sym = ('A2', 'A2'), no. elements = 91788  3.06%
# n = 1, sym = ('A2', 'B1'), no. elements = 311654  10.388%
# n = 1, sym = ('B1', 'A2'), no. elements = 311448  10.382%
# n = 1, sym = ('B1', 'B1'), no. elements = 91588  3.053%
# n = 1, sym = ('B2', 'A1'), no. elements = 319766  10.659%
# n = 1, sym = ('B2', 'B2'), no. elements = 93887  3.13%
# store matrix elements for J1 = 58 J2 = 60, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 90955  3.032%
# n = 0, sym = ('A1', 'B2'), no. elements = 317640  10.588%
# n = 0, sym = ('A2', 'A2'), no. elements = 88621  2.954%
# n = 0, sym = ('A2', 'B1'), no. elements = 322548  10.752%
# n = 0, sym = ('B1', 'A2'), no. elements = 322397  10.747%
# n = 0, sym = ('B1', 'B1'), no. elements = 89231  2.974%
# n = 0, sym = ('B2', 'A1'), no. elements = 317954  10.598%
# n = 0, sym = ('B2', 'B2'), no. elements = 91824  3.061%
# n = 1, sym = ('A1', 'A1'), no. elements = 90955  3.032%
# n = 1, sym = ('A1', 'B2'), no. elements = 317640  10.588%
# n = 1, sym = ('A2', 'A2'), no. elements = 88621  2.954%
# n = 1, sym = ('A2', 'B1'), no. elements = 322548  10.752%
# n = 1, sym = ('B1', 'A2'), no. elements = 322397  10.747%
# n = 1, sym = ('B1', 'B1'), no. elements = 89231  2.974%
# n = 1, sym = ('B2', 'A1'), no. elements = 317954  10.598%
# n = 1, sym = ('B2', 'B2'), no. elements = 91824  3.061%
# store matrix elements for J1 = 59 J2 = 57, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 87887  2.93%
# n = 0, sym = ('A1', 'B2'), no. elements = 316427  10.548%
# n = 0, sym = ('A2', 'A2'), no. elements = 91298  3.043%
# n = 0, sym = ('A2', 'B1'), no. elements = 316717  10.557%
# n = 0, sym = ('B1', 'A2'), no. elements = 315892  10.53%
# n = 0, sym = ('B1', 'B1'), no. elements = 91283  3.043%
# n = 0, sym = ('B2', 'A1'), no. elements = 315890  10.53%
# n = 0, sym = ('B2', 'B2'), no. elements = 87184  2.906%
# n = 1, sym = ('A1', 'A1'), no. elements = 87887  2.93%
# n = 1, sym = ('A1', 'B2'), no. elements = 316427  10.548%
# n = 1, sym = ('A2', 'A2'), no. elements = 91298  3.043%
# n = 1, sym = ('A2', 'B1'), no. elements = 316717  10.557%
# n = 1, sym = ('B1', 'A2'), no. elements = 315892  10.53%
# n = 1, sym = ('B1', 'B1'), no. elements = 91283  3.043%
# n = 1, sym = ('B2', 'A1'), no. elements = 315890  10.53%
# n = 1, sym = ('B2', 'B2'), no. elements = 87184  2.906%
# store matrix elements for J1 = 59 J2 = 58, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 93183  3.106%
# n = 0, sym = ('A1', 'B2'), no. elements = 319766  10.659%
# n = 0, sym = ('A2', 'A2'), no. elements = 91788  3.06%
# n = 0, sym = ('A2', 'B1'), no. elements = 311448  10.382%
# n = 0, sym = ('B1', 'A2'), no. elements = 311654  10.388%
# n = 0, sym = ('B1', 'B1'), no. elements = 91588  3.053%
# n = 0, sym = ('B2', 'A1'), no. elements = 318064  10.602%
# n = 0, sym = ('B2', 'B2'), no. elements = 93887  3.13%
# n = 1, sym = ('A1', 'A1'), no. elements = 93183  3.106%
# n = 1, sym = ('A1', 'B2'), no. elements = 319766  10.659%
# n = 1, sym = ('A2', 'A2'), no. elements = 91788  3.06%
# n = 1, sym = ('A2', 'B1'), no. elements = 311448  10.382%
# n = 1, sym = ('B1', 'A2'), no. elements = 311654  10.388%
# n = 1, sym = ('B1', 'B1'), no. elements = 91588  3.053%
# n = 1, sym = ('B2', 'A1'), no. elements = 318064  10.602%
# n = 1, sym = ('B2', 'B2'), no. elements = 93887  3.13%
# store matrix elements for J1 = 59 J2 = 59, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 99932  3.331%
# n = 0, sym = ('A1', 'B2'), no. elements = 295404  9.847%
# n = 0, sym = ('A2', 'A2'), no. elements = 97025  3.234%
# n = 0, sym = ('A2', 'B1'), no. elements = 284431  9.481%
# n = 0, sym = ('B1', 'A2'), no. elements = 284431  9.481%
# n = 0, sym = ('B1', 'B1'), no. elements = 97243  3.241%
# n = 0, sym = ('B2', 'A1'), no. elements = 295404  9.847%
# n = 0, sym = ('B2', 'B2'), no. elements = 100031  3.334%
# n = 1, sym = ('A1', 'A1'), no. elements = 99932  3.331%
# n = 1, sym = ('A1', 'B2'), no. elements = 295404  9.847%
# n = 1, sym = ('A2', 'A2'), no. elements = 97025  3.234%
# n = 1, sym = ('A2', 'B1'), no. elements = 284431  9.481%
# n = 1, sym = ('B1', 'A2'), no. elements = 284431  9.481%
# n = 1, sym = ('B1', 'B1'), no. elements = 97243  3.241%
# n = 1, sym = ('B2', 'A1'), no. elements = 295404  9.847%
# n = 1, sym = ('B2', 'B2'), no. elements = 100031  3.334%
# store matrix elements for J1 = 59 J2 = 60, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 92509  3.084%
# n = 0, sym = ('A1', 'B2'), no. elements = 315723  10.524%
# n = 0, sym = ('A2', 'A2'), no. elements = 94181  3.139%
# n = 0, sym = ('A2', 'B1'), no. elements = 321440  10.715%
# n = 0, sym = ('B1', 'A2'), no. elements = 321222  10.707%
# n = 0, sym = ('B1', 'B1'), no. elements = 94437  3.148%
# n = 0, sym = ('B2', 'A1'), no. elements = 314111  10.47%
# n = 0, sym = ('B2', 'B2'), no. elements = 93132  3.104%
# n = 1, sym = ('A1', 'A1'), no. elements = 92509  3.084%
# n = 1, sym = ('A1', 'B2'), no. elements = 315723  10.524%
# n = 1, sym = ('A2', 'A2'), no. elements = 94181  3.139%
# n = 1, sym = ('A2', 'B1'), no. elements = 321440  10.715%
# n = 1, sym = ('B1', 'A2'), no. elements = 321222  10.707%
# n = 1, sym = ('B1', 'B1'), no. elements = 94437  3.148%
# n = 1, sym = ('B2', 'A1'), no. elements = 314111  10.47%
# n = 1, sym = ('B2', 'B2'), no. elements = 93132  3.104%
# store matrix elements for J1 = 60 J2 = 58, delta J = 2
# n = 0, sym = ('A1', 'A1'), no. elements = 90955  3.032%
# n = 0, sym = ('A1', 'B2'), no. elements = 317954  10.598%
# n = 0, sym = ('A2', 'A2'), no. elements = 88621  2.954%
# n = 0, sym = ('A2', 'B1'), no. elements = 322397  10.747%
# n = 0, sym = ('B1', 'A2'), no. elements = 322548  10.752%
# n = 0, sym = ('B1', 'B1'), no. elements = 89231  2.974%
# n = 0, sym = ('B2', 'A1'), no. elements = 317640  10.588%
# n = 0, sym = ('B2', 'B2'), no. elements = 91824  3.061%
# n = 1, sym = ('A1', 'A1'), no. elements = 90955  3.032%
# n = 1, sym = ('A1', 'B2'), no. elements = 317954  10.598%
# n = 1, sym = ('A2', 'A2'), no. elements = 88621  2.954%
# n = 1, sym = ('A2', 'B1'), no. elements = 322397  10.747%
# n = 1, sym = ('B1', 'A2'), no. elements = 322548  10.752%
# n = 1, sym = ('B1', 'B1'), no. elements = 89231  2.974%
# n = 1, sym = ('B2', 'A1'), no. elements = 317640  10.588%
# n = 1, sym = ('B2', 'B2'), no. elements = 91824  3.061%
# store matrix elements for J1 = 60 J2 = 59, delta J = 1
# n = 0, sym = ('A1', 'A1'), no. elements = 92509  3.084%
# n = 0, sym = ('A1', 'B2'), no. elements = 314111  10.47%
# n = 0, sym = ('A2', 'A2'), no. elements = 94181  3.139%
# n = 0, sym = ('A2', 'B1'), no. elements = 321222  10.707%
# n = 0, sym = ('B1', 'A2'), no. elements = 321440  10.715%
# n = 0, sym = ('B1', 'B1'), no. elements = 94437  3.148%
# n = 0, sym = ('B2', 'A1'), no. elements = 315723  10.524%
# n = 0, sym = ('B2', 'B2'), no. elements = 93132  3.104%
# n = 1, sym = ('A1', 'A1'), no. elements = 92509  3.084%
# n = 1, sym = ('A1', 'B2'), no. elements = 314111  10.47%
# n = 1, sym = ('A2', 'A2'), no. elements = 94181  3.139%
# n = 1, sym = ('A2', 'B1'), no. elements = 321222  10.707%
# n = 1, sym = ('B1', 'A2'), no. elements = 321440  10.715%
# n = 1, sym = ('B1', 'B1'), no. elements = 94437  3.148%
# n = 1, sym = ('B2', 'A1'), no. elements = 315723  10.524%
# n = 1, sym = ('B2', 'B2'), no. elements = 93132  3.104%
# store matrix elements for J1 = 60 J2 = 60, delta J = 0
# n = 0, sym = ('A1', 'A1'), no. elements = 96515  3.217%
# n = 0, sym = ('A1', 'B2'), no. elements = 282760  9.425%
# n = 0, sym = ('A2', 'A2'), no. elements = 100844  3.361%
# n = 0, sym = ('A2', 'B1'), no. elements = 297611  9.92%
# n = 0, sym = ('B1', 'A2'), no. elements = 297611  9.92%
# n = 0, sym = ('B1', 'B1'), no. elements = 101414  3.38%
# n = 0, sym = ('B2', 'A1'), no. elements = 282760  9.425%
# n = 0, sym = ('B2', 'B2'), no. elements = 97043  3.235%
# n = 1, sym = ('A1', 'A1'), no. elements = 96515  3.217%
# n = 1, sym = ('A1', 'B2'), no. elements = 282760  9.425%
# n = 1, sym = ('A2', 'A2'), no. elements = 100844  3.361%
# n = 1, sym = ('A2', 'B1'), no. elements = 297611  9.92%
# n = 1, sym = ('B1', 'A2'), no. elements = 297611  9.92%
# n = 1, sym = ('B1', 'B1'), no. elements = 101414  3.38%
# n = 1, sym = ('B2', 'A1'), no. elements = 282760  9.425%
# n = 1, sym = ('B2', 'B2'), no. elements = 97043  3.235%

# %%
pmax = 20
rank = 1

min_J = 50
max_J = 60

state_ind_list = {sym: np.arange(1000) for sym in C2V_IRREPS}

# read vibrational matrix elements of spin-rotation tensors

with h5py.File(f"h2s_vibme_pmax{pmax}.h5", "r") as h5:
    dipole_vib = h5["dipole-moment"][:]

# compute rovibrational matrix elements and store them in file

for J1 in range(min_J, max_J + 1):
    for J2 in range(min_J, max_J + 1):
        dJ = abs(J1 - J2)
        if dJ > 1:
            continue

        dipole_me = tensor_rovib_me(
            rank,
            J1,
            J2,
            dipole_vib,
            state_ind_list1=state_ind_list,
            state_ind_list2=state_ind_list,
            tol=1e-6,
        )  # Debye units

        if dipole_me:
            print(f"store matrix elements for J1 = {J1} J2 = {J2}, delta J = {dJ}")
            with h5py.File(f"h2s_dipole_me_pmax{pmax}_j{J1}_j{J2}.h5", "w") as h5:
                for (sym1, sym2), me in dipole_me.items():
                    print(
                        f"sym = {(sym1, sym2)}, no. elements = {len(me.data)}  "
                        + f"{round(len(me.data)/np.prod(me.shape)*100,3)}%"
                    )
                    h5.create_dataset(f"{sym1}/{sym2}/data", data=me.data)
                    h5.create_dataset(f"{sym1}/{sym2}/indices", data=me.indices)
                    h5.create_dataset(f"{sym1}/{sym2}/indptr", data=me.indptr)
                    h5.create_dataset(f"{sym1}/{sym2}/shape", data=me.shape)
# Out:
# store energies for J = 0, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 1, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 2, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 3, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 4, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 5, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 6, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 7, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 8, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 9, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store energies for J = 10, no. states = [('A1', 10), ('A2', 10), ('B1', 10), ('B2', 10)]
# store matrix elements for J1 = 0 J2 = 1, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 1 J2 = 0, delta J = 1
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# store matrix elements for J1 = 1 J2 = 1, delta J = 0
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 1 J2 = 2, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 2 J2 = 1, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 2 J2 = 2, delta J = 0
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 2 J2 = 3, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 3 J2 = 2, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 3 J2 = 3, delta J = 0
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 3 J2 = 4, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 4 J2 = 3, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 4 J2 = 4, delta J = 0
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 4 J2 = 5, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 5 J2 = 4, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 5 J2 = 5, delta J = 0
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
# store matrix elements for J1 = 5 J2 = 6, delta J = 1
# sym = ('A1', 'A2'), no. elements = 100  100.0%
# sym = ('A2', 'A1'), no. elements = 100  100.0%
# sym = ('B1', 'B2'), no. elements = 100  100.0%
# sym = ('B2', 'B1'), no. elements = 100  100.0%
