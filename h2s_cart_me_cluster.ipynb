# %%
! export JAX_PLATFORMS=cpu
# Out:
# /gpfs/cfel/group/cmi/common/psi4/psi4conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %% [markdown]
# # Rovibrational matrix elements of Cartesian tensor operators
#
# Compute rovibrational matrix elements of spin-rotation tensors on $\text{H}_1$ and $\text{H}_2$ atoms and electric dipole moment of $\text{H}_2\text{S}$.
#
# Here, calculations will be performed only for rotational cluster states.

# %%
from typing import Dict, List

import h5py
import numpy as np
from jax import config
from jax import numpy as jnp
from rovib.cartens import CART_IND
from rovib.symtop import threej_wang

config.update("jax_enable_x64", True)

# %% [markdown]
# The rovibrational matrix elements of a Cartesian tensor operator $T$ of rank $\Omega$ are calculated using the following formula
#
# $$
# T_{\omega}^{(J',l',J,l)}=\sum_{v',k'}\sum_{v,k}c_{v',k'}^{(J',\Gamma',l')*}c_{v,k}^{(J,\Gamma,l)}(-1)^{k'}\sum_{\sigma=-\omega}^{\omega}\sum_{\alpha}
# \left(\begin{array}{ccc}
# J & \omega & J' \\
# k & \sigma & -k'\\
# \end{array}\right)
# U_{\omega\sigma,\alpha}^{(\Omega)}\langle v'|\bar{T}_{\alpha}|v\rangle.
# $$
#
# Here, $\omega=0..\Omega$, $\alpha=x,y,z$ and $xx,xy,xz,...zz$ for $\Omega=1$ and 2, respectively,
# $\bar{T}_{\alpha}$ is the electronic tensor (e.g., dipole moment, see `h2s_dipole.py`, or spin-rotation tensor, see `h2s_spinrot.py`),
# $v$ and $k$ denote the vibrational and rotational quanta,
# $J$ and $\Gamma$ denote 'good' quantum numbers of the rotational angular momentum and the state symmetry, and $l$ is the state running index within
# a set of states with the same $J$ and $\Gamma$.
# The rovibrational state expansion coefficients $c_{v,k}^{(J,\Gamma,l)}$
# are computed in `h2s_rovib.ipynb` and stored in seperate files
# for different values of $J$ quanta.
# The matrix $U_{\omega\sigma,\alpha}^{(\Omega)}$ transforms Cartesian tensor of rank $\Omega$ into its spherical-tensor representation
# (see `cartens.UMAT_CART_TO_SPHER`).
#
# The rotational part of the expression
# $$
# R_{\omega,k',k,\alpha\beta}^{(J',J)} = \sum_{\sigma=-\omega}^{\omega}
# \left(\begin{array}{ccc}
# J & \omega & J' \\
# k & \sigma & -k'\\
# \end{array}\right)
# U_{\omega\sigma,\alpha\beta}^{(\Omega)}
# $$
# is computed by the `symtop.threej_wang` function where it is transformed from the symmetric-top basis $|J,k\rangle$ ($k=-J..J$) into the so-called Wang's symmetry-adapted basis $|J,k,\tau\rangle$ ($k=0..J$, $\tau=0,1$ is partity as $(-1)^\tau$).
#
# The vibrational matrix elements
# $$
# V_{v',v,\alpha} = \langle v'|\bar{T}_{\alpha}|v\rangle
# $$
# are computed in `h2s_rovib.ipynb` and stored in file.
#
# -------

# %% [markdown]
# Define functions to load the energies and quantum numbers for selected rovibrational states (`rovib_states`) and to compute the above matrix elements (`tensor_rovib_me`).

# %%
def rovib_states(j: int, state_ind_list: Dict[str, List[int]] = None, pmax: int = 20):
    """Reads rovibrational energies and quanta stored in files for different values
    of the J quantum number (the files are created in `h2s_rovib.ipynb`).

    Optionally, `state_ind_list[symmetry][<list of state indices>]`
    can be used to select specific states by their indices
    for different symmetries.
    """
    h5 = h5py.File(f"h2s_coefficients_pmax{pmax}_j{j}.h5", "r")
    energies = {}
    quanta = {}
    vib_indices = {}
    rot_indices = {}
    coefficients = {}
    for sym in h5["energies"].keys():
        enr = h5["energies"][sym][:]
        coefs = h5["coefficients"][sym][:]
        vind = h5["vib-indices"][sym][:]
        rind = h5["rot-indices"][sym][:]
        qua = np.array(
            [elem[0].decode("utf-8").split(",") for elem in h5["quanta"][sym][:]]
        )
        if state_ind_list is not None and sym in state_ind_list:
            energies[sym] = enr[state_ind_list[sym]]
            quanta[sym] = qua[state_ind_list[sym]]
            coefficients[sym] = coefs[:, state_ind_list[sym]]
        else:
            energies[sym] = enr
            quanta[sym] = qua
            coefficients[sym] = coefs
        vib_indices[sym] = vind
        rot_indices[sym] = rind
    return energies, quanta, vib_indices, rot_indices, coefficients

# %%
def tensor_rovib_me(
    rank: int,
    j1: int,
    j2: int,
    vib_me: np.ndarray,
    state_ind_list1: Dict[str, List[int]] = None,
    state_ind_list2: Dict[str, List[int]] = None,
    pmax: int = 20,
    linear: bool = False,
):
    """Computes rovibrational matrix elements of a Cartesian tensor operator.

    This function calculates the rovibrational matrix elements using wavefunctions stored in
    separate files for different values of the J quantum number (the files are creaed in `h2s_rovib.ipynb`).
    The computation is performed for the specified bra (`j1`) and ket (`j2`) values of the J
    quantum number.

    Optionally, `state_ind_list1[symmetry][<list of state indices>]` and `state_ind_list2[...]`
    can be used to select specific bra and ket states by their indices for different symmetries.
    """

    # determine the order of Cartesian indices in the Cartesian-to-spherical tensor
    #   transformation matrix (in cartens.CART_IND and symtop.threej_wang)
    cart_ind = [["xyz".index(x) for x in elem] for elem in CART_IND[rank]]

    # reshape vibrational matrix elements such that the order of Cartesian indices
    #   correspond to the order in symtop.threej_wang output
    if rank == 1:
        vib_me2 = jnp.moveaxis(jnp.array([vib_me[:, :, i] for (i,) in cart_ind]), 0, -1)
    elif rank == 2:
        vib_me2 = jnp.moveaxis(
            jnp.array([vib_me[:, :, i, j] for (i, j) in cart_ind]), 0, -1
        )
    else:
        raise ValueError(
            f"Index mapping for tensor of rank = {rank} is not implemented"
        )

    # compute rotational matrix elements of three-j symbol contracted with
    #   Cartesian-to-spherical tensor transformation matrix
    jktau_list1, jktau_list2, rot_me = threej_wang(rank, j1, j2, linear=linear)
    # rot_me[omega].shape = (2*j1+1, 2*j2+1, ncart)

    h5_1 = h5py.File(f"h2s_coefficients_pmax{pmax}_j{j1}.h5", "r")
    h5_2 = h5py.File(f"h2s_coefficients_pmax{pmax}_j{j2}.h5", "r")

    res = {}

    for sym1 in h5_1["energies"].keys():
        enr1 = h5_1["energies"][sym1][:]
        coefs1 = h5_1["coefficients"][sym1][:]
        vind1 = h5_1["vib-indices"][sym1][:]
        rind1 = h5_1["rot-indices"][sym1][:]
        qua1 = np.array(
            [elem[0].decode("utf-8").split(",") for elem in h5_1["quanta"][sym1][:]]
        )

        if state_ind_list1 is not None:
            if sym1 in state_ind_list1:
                ind = state_ind_list1[sym1]
                enr1 = enr1[ind]
                coefs1 = coefs1[:, ind]
            else:
                continue

        for sym2 in h5_2["energies"].keys():
            enr2 = h5_2["energies"][sym2][:]
            coefs2 = h5_2["coefficients"][sym2][:]
            vind2 = h5_2["vib-indices"][sym2][:]
            rind2 = h5_2["rot-indices"][sym2][:]
            qua2 = np.array(
                [elem[0].decode("utf-8").split(",") for elem in h5_2["quanta"][sym2][:]]
            )

            if state_ind_list2 is not None:
                if sym2 in state_ind_list2:
                    ind = state_ind_list2[sym2]
                    enr2 = enr2[ind]
                    coefs2 = coefs2[:, ind]
                else:
                    continue

            vib_me_ = vib_me2[jnp.ix_(vind1, vind2)]
            me = []
            for omega in rot_me.keys():
                me_ = jnp.einsum(
                    "ijc,ijc->ij", vib_me_, rot_me[omega][jnp.ix_(rind1, rind2)]
                )
                me.append(jnp.einsum("ik,ij,jl->kl", jnp.conj(coefs1), me_, coefs2))
            res[((sym1, sym2))] = jnp.moveaxis(jnp.array(me), 0, -1)

    return res

# %% [markdown]
# Read the indices of rotational cluster states for different $J$ quanta, sored in file `h2s_cluster_states.txt`. These states were identified in `h2s_clusters.ipynb` notebook.

# %%
print("Rotational cluster states")

cluster_state_id = {}

with open("h2s_cluster_states_id.txt", "r") as fl:
    for line in fl:
        w = line.split()
        j = [int(w[0 + i * 12]) for i in range(4)]
        id = [int(w[1 + i * 12]) for i in range(4)]
        sym = [w[3 + i * 12] for i in range(4)]
        assert all(j[0] == elem for elem in j), f"Not all J quanta are equal: {j}"
        j_ = j[0]

        if j_ >= 50:
            cluster_state_id[j_] = {}
            for sym_, id_ in zip(sym, id):
                try:
                    cluster_state_id[j_][sym_].append(id_)
                except KeyError:
                    cluster_state_id[j_][sym_] = [id_]
            cluster_state_id[j_] = dict(sorted(cluster_state_id[j_].items()))
            print(f"J = {j_}, cluster-state IDs: {cluster_state_id[j_]}")
# Out:
# Rotational cluster states
# J = 50, cluster-state IDs: {'A1': [280], 'A2': [242], 'B1': [242], 'B2': [277]}
# J = 51, cluster-state IDs: {'A1': [267], 'A2': [299], 'B1': [299], 'B2': [270]}
# J = 52, cluster-state IDs: {'A1': [327], 'A2': [291], 'B1': [291], 'B2': [324]}
# J = 53, cluster-state IDs: {'A1': [316], 'A2': [353], 'B1': [354], 'B2': [318]}
# J = 54, cluster-state IDs: {'A1': [387], 'A2': [345], 'B1': [344], 'B2': [385]}
# J = 55, cluster-state IDs: {'A1': [371], 'A2': [412], 'B1': [413], 'B2': [373]}
# J = 56, cluster-state IDs: {'A1': [450], 'A2': [399], 'B1': [399], 'B2': [447]}
# J = 57, cluster-state IDs: {'A1': [432], 'A2': [486], 'B1': [487], 'B2': [434]}
# J = 58, cluster-state IDs: {'A1': [523], 'A2': [469], 'B1': [468], 'B2': [520]}
# J = 59, cluster-state IDs: {'A1': [503], 'A2': [563], 'B1': [565], 'B2': [505]}
# J = 60, cluster-state IDs: {'A1': [600], 'A2': [544], 'B1': [542], 'B2': [599]}

# %% [markdown]
# Using the functions above, compute matrix elements of spin-rotation tensors and dipole moment for rotational cluster states at $J=50..60$; store matrix elements in files.

# %%
pmax = 20

# read vibrational matrix elements of spin-rotation tensors and dipole moment

with h5py.File(f"h2s_vibme_pmax{pmax}.h5", "r") as h5:
    sr_h1_vib = h5["spin-rotation"]["h1"][:]
    sr_h2_vib = h5["spin-rotation"]["h2"][:]
    dipole_vib = h5["dipole-moment"][:]

# compute rovibrational matrix elements and store them in file

with h5py.File(f"h2s_enr_cluster_pmax{pmax}.h5", "w") as h5:
    for j in cluster_state_id.keys():
        enr, qua, vind, rind, coefs = rovib_states(j, state_ind_list=cluster_state_id[j])
        print(
            f"store energies for J = {j}, states = {[(sym, np.round(val, 6)) for sym, val in enr.items()]}"
        )
        for sym in enr:
            qua_str = [",".join(elem) for elem in qua[sym]]
            max_len = max([len(elem) for elem in qua_str])
            qua_ascii = [elem.encode("ascii", "ignore") for elem in qua_str]
            h5.create_dataset(f"energies/{j}/{sym}", data=enr[sym])
            h5.create_dataset(f"coefficients/{j}/{sym}", data=coefs[sym])
            h5.create_dataset(f"vib-indices/{j}/{sym}", data=vind[sym])
            h5.create_dataset(f"rot-indices/{j}/{sym}", data=rind[sym])
            h5.create_dataset(
                f"quanta/{j}/{sym}", (len(qua_ascii), 1), f"S{max_len}", data=qua_ascii
            )
# Out:
# store energies for J = 50, states = [('A1', array([24708.8189])), ('A2', array([24708.818796])), ('B1', array([24708.8189])), ('B2', array([24708.818796]))]
# store energies for J = 51, states = [('A1', array([25447.364248])), ('A2', array([25447.36433])), ('B1', array([25447.364248])), ('B2', array([25447.36433]))]
# store energies for J = 52, states = [('A1', array([26191.945163])), ('A2', array([26191.945055])), ('B1', array([26191.945163])), ('B2', array([26191.945055]))]
# store energies for J = 53, states = [('A1', array([26942.107341])), ('A2', array([26942.110081])), ('B1', array([26942.108071])), ('B2', array([26942.110081]))]
# store energies for J = 54, states = [('A1', array([27697.400168])), ('A2', array([27697.39982])), ('B1', array([27697.400168])), ('B2', array([27697.39982]))]
# store energies for J = 55, states = [('A1', array([28457.345655])), ('A2', array([28457.345664])), ('B1', array([28457.345655])), ('B2', array([28457.345664]))]
# store energies for J = 56, states = [('A1', array([29221.469946])), ('A2', array([29221.469944])), ('B1', array([29221.469946])), ('B2', array([29221.469944]))]
# store energies for J = 57, states = [('A1', array([29989.284287])), ('A2', array([29989.284287])), ('B1', array([29989.284287])), ('B2', array([29989.284287]))]
# store energies for J = 58, states = [('A1', array([30760.288805])), ('A2', array([30760.288805])), ('B1', array([30760.288805])), ('B2', array([30760.288805]))]
# store energies for J = 59, states = [('A1', array([31533.970945])), ('A2', array([31533.970945])), ('B1', array([31533.970945])), ('B2', array([31533.970945]))]
# store energies for J = 60, states = [('A1', array([32309.804184])), ('A2', array([32309.804184])), ('B1', array([32309.804184])), ('B2', array([32309.804184]))]

# %%
for j1 in cluster_state_id.keys():
    for j2 in cluster_state_id.keys():
        dj = abs(j1 - j2)

        # neglect off-diagonal coupling between different J because of the large energy gap
        if dj>0:
            continue

        if dj <= 1:
            dipole_me = tensor_rovib_me(
                1,
                j1,
                j2,
                dipole_vib,
                state_ind_list1=cluster_state_id[j1],
                state_ind_list2=cluster_state_id[j2],
            )  # Debye units
        else:
            dipole_me = {}

        if dj <= 2:
            sr1_me = tensor_rovib_me(
                2,
                j1,
                j2,
                sr_h1_vib,
                state_ind_list1=cluster_state_id[j1],
                state_ind_list2=cluster_state_id[j2],
            )
            sr2_me = tensor_rovib_me(
                2,
                j1,
                j2,
                sr_h2_vib,
                state_ind_list1=cluster_state_id[j1],
                state_ind_list2=cluster_state_id[j2],
            )
        else:
            sr1_me = {}
            sr2_me = {}

        if dipole_me or sr1_me or sr2_me:
            print(f"store matrix elements for J1 = {j1} J2 = {j2}, delta J = {dj}")
            with h5py.File(f"h2s_me_cluster_pmax{pmax}_j{j1}_j{j2}.h5", "w") as h5:
                for label, oper in zip(
                    ("dipole", "spin-rotation-H1", "spin-rotation-H2"),
                    (dipole_me, sr1_me, sr2_me),
                ):
                    for (sym1, sym2), me in oper.items():
                        print(f"{label}, sym = {(sym1, sym2)}, shape = {me.shape}, val = {me}")
                        h5.create_dataset(f"{label}/{sym1}/{sym2}", data=me)
# Out:
# store matrix elements for J1 = 50 J2 = 50, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.05745297j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.-5.37638729e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.-0.05745297j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.-5.37337889e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.+5.37638729e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.05745297j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.+5.37337889e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.-0.05745297j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.73188857e+00+0.j -1.62755768e-21+0.j -6.41100626e-03+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-3.91696211e-16+0.j  3.50322401e-08+0.j -2.21833679e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.73188857e+00+0.j -1.77528001e-21+0.j -6.41110160e-03+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[3.91696283e-16+0.j 3.50296056e-08+0.j 2.21833679e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[ 3.91696163e-16+0.j -3.50296056e-08+0.j  2.21833679e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.73188857e+00+0.j -1.62773792e-21+0.j -6.41100620e-03+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-3.91696330e-16+0.j -3.50322401e-08+0.j -2.21833679e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.73188857e+00+0.j -1.77528702e-21+0.j -6.41110160e-03+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.73188857e+00+0.j  1.62755768e-21+0.j -6.41100626e-03+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-3.91696211e-16+0.j -3.50322401e-08+0.j  2.21833679e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.73188857e+00+0.j  1.77528001e-21+0.j -6.41110160e-03+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[ 3.91696283e-16+0.j -3.50296056e-08+0.j -2.21833679e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[ 3.91696163e-16+0.j  3.50296056e-08+0.j -2.21833679e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.73188857e+00+0.j  1.62773792e-21+0.j -6.41100620e-03+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-3.91696330e-16+0.j  3.50322401e-08+0.j  2.21833679e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.73188857e+00+0.j  1.77528702e-21+0.j -6.41110160e-03+0.j]]]
# store matrix elements for J1 = 51 J2 = 51, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.-0.05685721j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.-5.67060402e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.05685721j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.+5.67341288e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.+5.67060402e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.05685721j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.-5.67341288e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.-0.05685721j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[ 2.70523536e+00+0.j -5.23286159e-21+0.j  7.63995391e-03+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[5.09738231e-16+0.j 2.78571598e-08+0.j 2.20026755e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[ 2.70523536e+00+0.j -5.36784278e-21+0.j  7.63992077e-03+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[ 5.09738174e-16+0.j -2.78921971e-08+0.j  2.20026754e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[5.09738257e-16+0.j 2.78921971e-08+0.j 2.20026754e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[ 2.70523536e+00+0.j -5.23285757e-21+0.j  7.63995391e-03+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[ 5.09738148e-16+0.j -2.78571598e-08+0.j  2.20026755e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[ 2.70523536e+00+0.j -5.36787886e-21+0.j  7.63992064e-03+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[2.70523536e+00+0.j 5.23286159e-21+0.j 7.63995391e-03+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[ 5.09738231e-16+0.j -2.78571598e-08+0.j -2.20026755e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[2.70523536e+00+0.j 5.36784278e-21+0.j 7.63992077e-03+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[ 5.09738174e-16+0.j  2.78921971e-08+0.j -2.20026754e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[ 5.09738257e-16+0.j -2.78921971e-08+0.j -2.20026754e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[2.70523536e+00+0.j 5.23285757e-21+0.j 7.63995391e-03+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[ 5.09738148e-16+0.j  2.78571598e-08+0.j -2.20026755e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[2.70523536e+00+0.j 5.36787886e-21+0.j 7.63992064e-03+0.j]]]
# store matrix elements for J1 = 52 J2 = 52, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.05623661j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.+5.97763566e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.-0.05623661j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.-5.97353041e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.-5.97763566e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.-0.05623661j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.+5.97353041e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.05623661j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.67934735e+00+0.j  1.23089082e-20+0.j -8.77410987e-03+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-6.28036953e-16+0.j  3.67035303e-08+0.j -2.18245762e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.67934735e+00+0.j  1.21033337e-20+0.j -8.77402200e-03+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-6.28037056e-16+0.j -3.67016967e-08+0.j -2.18245763e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-6.28036963e-16+0.j  3.67016967e-08+0.j -2.18245763e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.67934735e+00+0.j  1.23088985e-20+0.j -8.77410987e-03+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-6.28037047e-16+0.j -3.67035303e-08+0.j -2.18245762e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.67934735e+00+0.j  1.21034237e-20+0.j -8.77402194e-03+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.67934735e+00+0.j -1.23089082e-20+0.j -8.77410987e-03+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-6.28036953e-16+0.j -3.67035303e-08+0.j  2.18245762e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.67934735e+00+0.j -1.21033337e-20+0.j -8.77402200e-03+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-6.28037056e-16+0.j  3.67016967e-08+0.j  2.18245763e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-6.28036963e-16+0.j -3.67016967e-08+0.j  2.18245763e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.67934735e+00+0.j -1.23088985e-20+0.j -8.77410987e-03+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-6.28037047e-16+0.j  3.67035303e-08+0.j  2.18245762e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.67934735e+00+0.j -1.21034237e-20+0.j -8.77402194e-03+0.j]]]
# store matrix elements for J1 = 53 J2 = 53, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.05550766j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.-6.48577394e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.-0.05550766j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.+6.29441731e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.+6.48577262e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.-0.05553727j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.-6.29441731e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.05553727j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[ 2.65418860e+00+0.j -1.23932097e-20+0.j  9.71393997e-03+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-7.43375808e-16+0.j -9.29606631e-07+0.j -2.16177267e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[ 2.65418860e+00+0.j -1.89139517e-20+0.j  9.82369400e-03+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-7.43829412e-16+0.j  6.81329612e-07+0.j -2.16292665e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-7.43830452e-16+0.j -6.81329612e-07+0.j -2.16292665e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[ 2.65418860e+00+0.j -1.36571916e-20+0.j  9.77796891e-03+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-7.43374219e-16+0.j  9.29606631e-07+0.j -2.16177267e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[ 2.65418860e+00+0.j -1.89139549e-20+0.j  9.82369400e-03+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[2.65418860e+00+0.j 1.23932097e-20+0.j 9.71393997e-03+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-7.43375808e-16+0.j  9.29606631e-07+0.j  2.16177267e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[2.65418860e+00+0.j 1.89139517e-20+0.j 9.82369400e-03+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-7.43829412e-16+0.j -6.81329612e-07+0.j  2.16292665e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-7.43830452e-16+0.j  6.81329612e-07+0.j  2.16292665e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[2.65418860e+00+0.j 1.36571916e-20+0.j 9.77796891e-03+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-7.43374219e-16+0.j -9.29606631e-07+0.j  2.16177267e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[2.65418860e+00+0.j 1.89139549e-20+0.j 9.82369400e-03+0.j]]]
# store matrix elements for J1 = 54 J2 = 54, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.05490719j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.-6.68734105e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.-0.05490719j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.-6.64752387e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.+6.68734105e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.05490719j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.+6.64752387e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.-0.05490719j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.62972551e+00+0.j  2.63651997e-20+0.j -1.07913191e-02+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-8.57693471e-16+0.j  1.19180826e-07+0.j -2.14758434e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.62972551e+00+0.j  2.54843257e-20+0.j -1.07982933e-02+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[8.57693612e-16+0.j 1.19192436e-07+0.j 2.14758434e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[ 8.57693461e-16+0.j -1.19192436e-07+0.j  2.14758434e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.62972551e+00+0.j  2.63652255e-20+0.j -1.07913190e-02+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-8.57693621e-16+0.j -1.19180826e-07+0.j -2.14758434e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.62972551e+00+0.j  2.54836853e-20+0.j -1.07982933e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.62972551e+00+0.j -2.63651997e-20+0.j -1.07913191e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-8.57693471e-16+0.j -1.19180826e-07+0.j  2.14758434e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.62972551e+00+0.j -2.54843257e-20+0.j -1.07982933e-02+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[ 8.57693612e-16+0.j -1.19192436e-07+0.j -2.14758434e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[ 8.57693461e-16+0.j  1.19192436e-07+0.j -2.14758434e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.62972551e+00+0.j -2.63652255e-20+0.j -1.07913190e-02+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-8.57693621e-16+0.j  1.19180826e-07+0.j  2.14758434e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.62972551e+00+0.j -2.54836853e-20+0.j -1.07982933e-02+0.j]]]
# store matrix elements for J1 = 55 J2 = 55, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.-0.05419432j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.+7.03123045e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.05419432j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.-7.03195392e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.-7.03123045e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.05419432j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.+7.03195392e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.-0.05419432j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[ 2.60592660e+00+0.j -3.08054864e-20+0.j  1.17068962e-02+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-9.65273370e-16+0.j -3.14437782e-09+0.j -2.13072110e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[ 2.60592660e+00+0.j -3.08321573e-20+0.j  1.17068503e-02+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-9.65273341e-16+0.j  3.14843835e-09+0.j -2.13072110e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-9.65273344e-16+0.j -3.14843836e-09+0.j -2.13072110e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[ 2.60592660e+00+0.j -3.08055948e-20+0.j  1.17068961e-02+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-9.65273367e-16+0.j  3.14437782e-09+0.j -2.13072110e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[ 2.60592660e+00+0.j -3.08321431e-20+0.j  1.17068503e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[2.60592660e+00+0.j 3.08054864e-20+0.j 1.17068962e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-9.65273370e-16+0.j  3.14437782e-09+0.j  2.13072110e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[2.60592660e+00+0.j 3.08321573e-20+0.j 1.17068503e-02+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-9.65273341e-16+0.j -3.14843835e-09+0.j  2.13072110e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-9.65273344e-16+0.j  3.14843836e-09+0.j  2.13072110e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[2.60592660e+00+0.j 3.08055948e-20+0.j 1.17068961e-02+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-9.65273367e-16+0.j -3.14437782e-09+0.j  2.13072110e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[2.60592660e+00+0.j 3.08321431e-20+0.j 1.17068503e-02+0.j]]]
# store matrix elements for J1 = 56 J2 = 56, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.-0.05343755j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.-7.48869958e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.05343755j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.+7.48866737e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.+7.48869958e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.05343755j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.-7.48866737e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.-0.05343755j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.58276235e+00+0.j  3.52741577e-20+0.j -1.25575606e-02+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-1.06569626e-15+0.j  6.63699052e-10+0.j -2.11405918e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.58276235e+00+0.j  3.52684415e-20+0.j -1.25575701e-02+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-1.06569627e-15+0.j -6.29190002e-10+0.j -2.11405918e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-1.06569626e-15+0.j  6.29190003e-10+0.j -2.11405918e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.58276235e+00+0.j  3.52741647e-20+0.j -1.25575606e-02+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-1.06569627e-15+0.j -6.63699052e-10+0.j -2.11405918e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.58276235e+00+0.j  3.52683652e-20+0.j -1.25575701e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.58276235e+00+0.j -3.52741577e-20+0.j -1.25575606e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-1.06569626e-15+0.j -6.63699052e-10+0.j  2.11405918e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.58276235e+00+0.j -3.52684415e-20+0.j -1.25575701e-02+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-1.06569627e-15+0.j  6.29190002e-10+0.j  2.11405918e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-1.06569626e-15+0.j -6.29190003e-10+0.j  2.11405918e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.58276235e+00+0.j -3.52741647e-20+0.j -1.25575606e-02+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-1.06569627e-15+0.j  6.63699052e-10+0.j  2.11405918e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.58276235e+00+0.j -3.52683652e-20+0.j -1.25575701e-02+0.j]]]
# store matrix elements for J1 = 57 J2 = 57, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.0526317j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.+8.0589453e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.-0.0526317j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.-8.05893265e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.-8.0589453e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.-0.0526317j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.+8.05893265e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.0526317j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[ 2.56020504e+00+0.j -3.86279547e-20+0.j  1.33585437e-02+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[1.15756041e-15+0.j 1.01693146e-10+0.j 2.09769452e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[ 2.56020504e+00+0.j -3.86308473e-20+0.j  1.33585423e-02+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[ 1.15756041e-15+0.j -5.11110219e-12+0.j  2.09769451e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[1.15756041e-15+0.j 5.11109993e-12+0.j 2.09769451e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[ 2.56020504e+00+0.j -3.86280349e-20+0.j  1.33585437e-02+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[ 1.15756041e-15+0.j -1.01693149e-10+0.j  2.09769452e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[ 2.56020504e+00+0.j -3.86308062e-20+0.j  1.33585425e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[2.56020504e+00+0.j 3.86279547e-20+0.j 1.33585437e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[ 1.15756041e-15+0.j -1.01693146e-10+0.j -2.09769452e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[2.56020504e+00+0.j 3.86308473e-20+0.j 1.33585423e-02+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[ 1.15756041e-15+0.j  5.11110219e-12+0.j -2.09769451e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[ 1.15756041e-15+0.j -5.11109993e-12+0.j -2.09769451e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[2.56020504e+00+0.j 3.86280349e-20+0.j 1.33585437e-02+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[ 1.15756041e-15+0.j  1.01693149e-10+0.j -2.09769452e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[2.56020504e+00+0.j 3.86308062e-20+0.j 1.33585425e-02+0.j]]]
# store matrix elements for J1 = 58 J2 = 58, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.0517676j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.-8.79983933e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.-0.0517676j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.-8.79986763e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.+8.79983933e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.0517676j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.+8.79986763e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.-0.0517676j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.53822862e+00+0.j  4.07480771e-20+0.j -1.41178094e-02+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-1.23979685e-15+0.j  1.02022814e-10+0.j -2.08162910e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.53822862e+00+0.j  4.07468563e-20+0.j -1.41178098e-02+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[1.23979679e-15+0.j 3.29938803e-11+0.j 2.08162910e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[ 1.23979679e-15+0.j -3.29938647e-11+0.j  2.08162910e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.53822862e+00+0.j  4.07479873e-20+0.j -1.41178094e-02+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-1.23979685e-15+0.j -1.02022830e-10+0.j -2.08162910e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.53822862e+00+0.j  4.07462627e-20+0.j -1.41178100e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.53822862e+00+0.j -4.07480771e-20+0.j -1.41178094e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-1.23979685e-15+0.j -1.02022814e-10+0.j  2.08162910e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.53822862e+00+0.j -4.07468563e-20+0.j -1.41178098e-02+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[ 1.23979679e-15+0.j -3.29938803e-11+0.j -2.08162910e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[ 1.23979679e-15+0.j  3.29938647e-11+0.j -2.08162910e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.53822862e+00+0.j -4.07479873e-20+0.j -1.41178094e-02+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-1.23979685e-15+0.j  1.02022830e-10+0.j  2.08162910e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.53822862e+00+0.j -4.07462627e-20+0.j -1.41178100e-02+0.j]]]
# store matrix elements for J1 = 59 J2 = 59, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.05083381j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.-9.79157531e-16j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.-0.05083381j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.+9.79151435e-16j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.+9.79157531e-16j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.-0.05083381j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.-9.79151435e-16j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.05083381j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[ 2.51680859e+00+0.j -4.15562626e-20+0.j  1.48433609e-02+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-1.31176064e-15+0.j -3.25215329e-11+0.j -2.06586387e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[ 2.51680859e+00+0.j -4.15569484e-20+0.j  1.48433605e-02+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-1.31176047e-15+0.j  4.38692677e-11+0.j -2.06586386e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-1.31176047e-15+0.j -4.38692603e-11+0.j -2.06586386e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[ 2.51680859e+00+0.j -4.15568022e-20+0.j  1.48433612e-02+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-1.31176064e-15+0.j  3.25215407e-11+0.j -2.06586387e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[ 2.51680859e+00+0.j -4.15570943e-20+0.j  1.48433605e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[2.51680859e+00+0.j 4.15562626e-20+0.j 1.48433609e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[-1.31176064e-15+0.j  3.25215329e-11+0.j  2.06586387e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[2.51680859e+00+0.j 4.15569484e-20+0.j 1.48433605e-02+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-1.31176047e-15+0.j -4.38692677e-11+0.j  2.06586386e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-1.31176047e-15+0.j  4.38692603e-11+0.j  2.06586386e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[2.51680859e+00+0.j 4.15568022e-20+0.j 1.48433612e-02+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[-1.31176064e-15+0.j -3.25215407e-11+0.j  2.06586387e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[2.51680859e+00+0.j 4.15570943e-20+0.j 1.48433605e-02+0.j]]]
# store matrix elements for J1 = 60 J2 = 60, delta J = 0
# dipole, sym = ('A1', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.04981613j]]]
# dipole, sym = ('A1', 'B1'), shape = (1, 1, 1), val = [[[0.+1.11410218e-15j]]]
# dipole, sym = ('A1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'A1'), shape = (1, 1, 1), val = [[[0.-0.04981613j]]]
# dipole, sym = ('A2', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('A2', 'B2'), shape = (1, 1, 1), val = [[[0.+1.11409253e-15j]]]
# dipole, sym = ('B1', 'A1'), shape = (1, 1, 1), val = [[[0.-1.11410218e-15j]]]
# dipole, sym = ('B1', 'A2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B1', 'B2'), shape = (1, 1, 1), val = [[[0.+0.04981613j]]]
# dipole, sym = ('B2', 'A1'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# dipole, sym = ('B2', 'A2'), shape = (1, 1, 1), val = [[[0.-1.11409253e-15j]]]
# dipole, sym = ('B2', 'B1'), shape = (1, 1, 1), val = [[[0.-0.04981613j]]]
# dipole, sym = ('B2', 'B2'), shape = (1, 1, 1), val = [[[0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.49592185e+00+0.j  4.10862198e-20+0.j -1.55433591e-02+0.j]]]
# spin-rotation-H1, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[1.37329464e-15+0.j 4.98782980e-11+0.j 2.05039920e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.49592185e+00+0.j  4.10865359e-20+0.j -1.55433587e-02+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-1.37329461e-15+0.j  5.03182384e-11+0.j -2.05039920e+00+0.j]]]
# spin-rotation-H1, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-1.37329461e-15+0.j -5.03182300e-11+0.j -2.05039920e+00+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.49592185e+00+0.j  4.10861214e-20+0.j -1.55433591e-02+0.j]]]
# spin-rotation-H1, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[ 1.37329464e-15+0.j -4.98783060e-11+0.j  2.05039920e+00+0.j]]]
# spin-rotation-H1, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H1, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.49592185e+00+0.j  4.10866124e-20+0.j -1.55433587e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A1'), shape = (1, 1, 3), val = [[[-2.49592185e+00+0.j -4.10862198e-20+0.j -1.55433591e-02+0.j]]]
# spin-rotation-H2, sym = ('A1', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A1', 'B2'), shape = (1, 1, 3), val = [[[ 1.37329464e-15+0.j -4.98782980e-11+0.j -2.05039920e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('A2', 'A2'), shape = (1, 1, 3), val = [[[-2.49592185e+00+0.j -4.10865359e-20+0.j -1.55433587e-02+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B1'), shape = (1, 1, 3), val = [[[-1.37329461e-15+0.j -5.03182384e-11+0.j  2.05039920e+00+0.j]]]
# spin-rotation-H2, sym = ('A2', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B1', 'A2'), shape = (1, 1, 3), val = [[[-1.37329461e-15+0.j  5.03182300e-11+0.j  2.05039920e+00+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B1'), shape = (1, 1, 3), val = [[[-2.49592185e+00+0.j -4.10861214e-20+0.j -1.55433591e-02+0.j]]]
# spin-rotation-H2, sym = ('B1', 'B2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A1'), shape = (1, 1, 3), val = [[[ 1.37329464e-15+0.j  4.98783060e-11+0.j -2.05039920e+00+0.j]]]
# spin-rotation-H2, sym = ('B2', 'A2'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B1'), shape = (1, 1, 3), val = [[[0.+0.j 0.+0.j 0.+0.j]]]
# spin-rotation-H2, sym = ('B2', 'B2'), shape = (1, 1, 3), val = [[[-2.49592185e+00+0.j -4.10866124e-20+0.j -1.55433587e-02+0.j]]]
